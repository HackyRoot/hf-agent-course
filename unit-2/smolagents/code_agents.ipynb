# %% [markdown]
# <a href="https://colab.research.google.com/github/HackyRoot/hf-agent-course/blob/main/unit-2/smolagents/code_agents.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Building Agents That Use Code
#
# This notebook is part of the [Hugging Face Agents Course](https://www.hf.co/learn/agents-course), a free Course from beginner to expert, where you learn to build Agents.
#
# ![Agents course share](https://huggingface.co/datasets/agents-course/course-images/resolve/main/en/communication/share.png)
#
# Alfred is planning a party at the Wayne family mansion and needs your help to ensure everything goes smoothly. To assist him, we'll apply what we've learned about how a multi-step `CodeAgent` operates.

# %% [markdown]
# ## Let's install the dependencies and login to our HF account to access the Inference API
#
# If you haven't installed `smolagents` yet, you can do so by running the following command:

# %%
# !pip install -q smolagents[litellm] -U
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 35.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 16.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 35.8 MB/s eta 0:00:00

# %% [markdown]
# Let's also login to the Hugging Face Hub to have access to the Inference API.

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from google.colab import userdata
from smolagents import LiteLLMModel

# Replace all calls to HfApiModel
gemini_model = LiteLLMModel(
    model_id="gemini/gemini-2.0-flash", # you can see other model names here: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models. It is important to prefix the name with "gemini/"
    api_key=userdata.get("gemini_api_key"),
    max_tokens=8192
)

# %% [markdown]
# ## Selecting a Playlist for the Party Using `smolagents`
#
# An important part of a successful party is the music. Alfred needs some help selecting the playlist. Luckily, `smolagents` has got us covered! We can build an agent capable of searching the web using DuckDuckGo. To give the agent access to this tool, we include it in the tool list when creating the agent.
#
# For the model, we'll rely on `HfApiModel`, which provides access to Hugging Face's [Inference API](https://huggingface.co/docs/api-inference/index). The default model is `"Qwen/Qwen2.5-Coder-32B-Instruct"`, which is performant and available for fast inference, but you can select any compatible model from the Hub.
#
# Running an agent is quite straightforward:

# %%
from smolagents import CodeAgent, DuckDuckGoSearchTool, HfApiModel

agent = CodeAgent(tools=[DuckDuckGoSearchTool()], model=gemini_model)

agent.run("Search for the best music recommendations for a party at the Wayne's mansion.")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Search for the best music recommendations for a party at the Wayne's mansion.                                   │
# │                                                                                                                 │
# ╰─ LiteLLMModel - gemini/gemini-2.0-flash ────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   search_results = web_search(query="music recommendations party Wayne's mansion")
#   print(search_results)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [late nights in the wayne manor | a bruce wayne rock/blues playlist](https://www.youtube.com/watch?v=oOdHCjj3jn4)
# these are songs that bruce wayne listens to while wandering the halls of the great wayne manor.find this playlist
# on my spotify: https://open.spotify.com/use...
#
# [The 75 Best Party Songs That Will Get Everyone Dancing -
# Gear4music](https://www.gear4music.com/blog/best-party-songs/)
# A party planner's list PA system/speakers. An epic party needs an epic PA system! When selecting a sound system for
# your party, the size of the room is crucial. A small room might need just a pair of compact speakers, while a
# larger space could benefit greatly from a subwoofer to boost bass frequencies.
#
# [Party on, Wayne! - playlist by Music League | Spotify](https://open.spotify.com/playlist/4J61XoHr2CINqRA1DV0ga7)
# Party on, Wayne! · Playlist · 17 songs · 4 likes
#
# [Party on, Wayne (classic) - playlist by Rachael Gallagher -
# Spotify](https://open.spotify.com/playlist/2oO5OWUvlBPj3AVhvl2P1t)
# Rachael Gallagher · Playlist · 911 songs · 4 likes
#
# [Party on, Wayne! - YouTube Music](https://music.youtube.com/playlist?list=PLXxuECYNOaw87L8fiV0UVlHQupKEwpIha)
# A new music service with official albums, singles, videos, remixes, live performances and more for Android, iOS and
# desktop. It's all here.
#
# [50 Songs on Every Event Planner's Playlist -
# Eventbrite](https://www.eventbrite.com/blog/event-planning-playlist-ds00/)
# Music sets the mood and provides the soundtrack (literally) for a memorable and exciting time. While the right
# songs can enhance the experience, the wrong event music can throw off the vibe. For example, fast-paced songs
# probably aren't the best fit for a formal gala. And smooth jazz is likely to lull your guests at a motivational
# conference.
#
# [Best Songs To Party: DJ's Ultimate Party Songs Playlist -
# Top40Weekly.com](https://top40weekly.com/best-songs-to-party/)
# The 2003 hip-hop hit "In da Club" by 50 Cent remains a party rap classic that never fails to get people on the
# dance floor. The song's catchy chorus, "Go, shorty, it's your birthday / We gon' party like it's your birthday,"
# has become a universal invitation to let loose and embrace the carefree spirit of the moment.
#
# [Party at the Mansion - playlist by Rich Campbell |
# Spotify](https://open.spotify.com/playlist/1sKU3Ts1nIJ1kDMfPEwsnO)
# Playlist · Party at the Mansion · 515 items · 29 likes. Playlist · Rich Campbell · 515 items · 29 likes. Playlist ·
# Party at the Mansion · 515 items · 29 likes ... Sign up to get unlimited songs and podcasts with occasional ads. No
# credit card needed. Sign up free-:--Change progress-:--Change volume. Company. About Jobs For the Record.
#
# [Wayne's World - Rate Your Music](https://rateyourmusic.com/list/JonFox/waynes_world/)
# It's Wayne's World It's Wayne's World It's party time It's excellent It's Wayne's World It's Wayne's World It's
# party time It's excellent Chicks go mental When we go down the street It's Wayne and Garth That they want to meet
# We're down in the basement Playing with our toys And if you don't like it You're a sphincter boy It's Wayne's World
# It's ...
#
# ['Wayne's World"s Iconic "Bohemian Rhapsody" Scene Still Rocks After 26
# ...](https://iloveclassicrock.com/party-on-bohemian/)
# "I Think We'll Go With A Little Bohemian Rhapsody!" In Wayne's World (1992), Saturday Night Live alumni Mike Myers
# and Dana Carvey paid tribute to Queen with their hilarious and heartwarming rendition of 'Bohemian Rhapsody'. The
# scene was momentous; not only did it introduce Queen to the MTV generation, but it thrust Queen back into the
# limelight, bringing 'Bohemian […]
#
# Out: None
# [Step 1: Duration 2.21 seconds| Input tokens: 2,223 | Output tokens: 75]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   search_results = web_search(query="late nights in the Wayne Manor playlist")
#   print(search_results)
#   search_results_2 = web_search(query="Party at the Mansion playlist")
#   print(search_results_2)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [late nights in the wayne manor | a bruce wayne rock/blues playlist](https://www.youtube.com/watch?v=oOdHCjj3jn4)
# these are songs that bruce wayne listens to while wandering the halls of the great wayne manor.find this playlist
# on my spotify: https://open.spotify.com/use...
#
# [WAYNE MANOR OFFICIAL PLAYLIST ("I should've stopped at ... -
# Spotify](https://open.spotify.com/playlist/12UvCfOYnytKMCjJOeyPEJ)
# WAYNE MANOR OFFICIAL PLAYLIST ("I should've stopped at one" —Bruce Wayne) · Playlist · 147 songs · 177 likes
#
# [late nights in the batcave part 6 | a batman grunge/rock playlist](https://www.youtube.com/watch?v=GKE9TFZ-qOM)
# these are songs that bruce wayne listens to as he spends his nights alone in the batcave. this is part 6.find this
# playlist on my spotify: https://open.spoti...
#
# [Late Night Playlist : Free Download, Borrow, and Streaming : Internet ...](https://archive.org/details/incognito4)
# Late Night Playlist Audio With External Links Item Preview ... Late Night Drive Item Size 197.5M . LANY, LAUV,
# TROYE SIVAN, JEREMY ZUCKER, ETC Addeddate 2024-02-25 11:47:59 Identifier incognito4 Scanner Internet Archive HTML5
# Uploader 1.7.0 . plus-circle Add ...
#
# [Your... - Inside Wayne Manor With Stephen Wayne and Friends -
# Facebook](https://www.facebook.com/insidewaynemanor/posts/your-friendly-monday-morning-reminder-the-the-playlist-fo
# r-the-ensemble-part-all/160670998856712/)
# Your friendly Monday morning reminder, the the playlist for "The Ensemble Part All Mixed Up Volume One" is
# available right here. And not all the songs were available so, you'll just have to listen to...
#
# [Late Nights Mixes - YouTube Music](https://music.youtube.com/playlist?list=PLUKVMnc-62lMFfRsYtKIz0BjjtR1HNqwX)
# All of our Late Nights Volumes in one playlist, listen to them all back to back with this playlist!
#
# [Stately Wayne Manor Radio - playlist by Spotify |
# Spotify](https://open.spotify.com/playlist/37i9dQZF1E4E228T8R66yj)
# Stately Wayne Manor Radio · Playlist · 50 songs
#
# [Late Night Vibes Playlist : Free Download, Borrow, and Streaming
# ...](https://archive.org/details/late-night-vibes-playlist)
# Late Night Vibes Playlist. Topics mix Item Size 41.1M . Late night vibes Addeddate 2022-06-17 07:45:31 Identifier
# late-night-vibes-playlist Scanner Internet Archive HTML5 Uploader 1.6.4 . plus-circle Add Review. comment. Reviews
# There are no reviews yet. Be the first one ...
#
# [Beneath Wayne Manor: Late Nights](https://beneathwaynemanor.blogspot.com/2005/09/late-nights.html)
# Come find out, for this blog is a history, no a saga, for only the past can be history and this has only just
# begun. Within these pages lies the adventures of two young caped crusaders. Tales of action and drama, comedy and
# horror, stream forth. Follow these events of Batman and Robin as they unfold under the shadow of the night.
#
# [late nights in the wayne manor part 2 | a bruce wayne rock/blues ...](https://www.youtube.com/watch?v=DBRSHk2XpmU)
# these are songs that bruce wayne listens to while wandering the halls of the great wayne manor. this is part 2.find
# this playlist on my spotify: https://open...
# ## Search Results
#
# [Party at the Mansion - playlist by Rich Campbell |
# Spotify](https://open.spotify.com/playlist/1sKU3Ts1nIJ1kDMfPEwsnO)
# Playlist · Party at the Mansion · 515 items · 29 likes. These cookies are necessary for the service to function and
# cannot be switched off in our systems.
#
# [Party at the mansion - playlist by Jonny - Spotify](https://open.spotify.com/playlist/1A1XTCxTWxSV4Vx30kWkg6)
# Playlist · Party at the mansion · 266 songs · 136 likes
#
# [party at the mansion - playlist by sarah smorholm |
# Spotify](https://open.spotify.com/playlist/7vxFKi7Zat4ZZX0S5AgCDM)
# party at the mansion · Playlist · 32 songs · 62 likes
#
# [Party at the Mansion - YouTube](https://www.youtube.com/playlist?list=PLJd9o86B_HyBRFaEf83aPIps2dUrxYwSc)
# Share your videos with friends, family, and the world
#
# [Seed Of 6ix (Feat. Juicy J) - Party At The Mansion [The Dunigans ...](https://www.youtube.com/watch?v=ers6oljF2LQ)
# Seed Of 6ix - Party At The Mansion (Feat. Juicy J) [The Dunigans Mixtape]TNHHHD - Top Notch Hip Hop HD (Channel
# Playlist)https://www.youtube.com/playlist?lis...
#
# [Listen to playlists featuring Party At The Mansion by Blackman The
# ...](https://soundcloud.com/blackman-the-great/party-at-the-mansion/sets)
# Listen to discovery playlists featuring Party At The Mansion by Blackman The Great on desktop and mobile.
#
# [Party at the Mansion Original Mix - Beatport](https://www.beatport.com/track/party-at-the-mansion/19095448)
# Download & Stream Horchata - Party at the Mansion (Original Mix) [Subline Audio] in highest quality | Find the
# latest releases here | #1 source for DJ Sets and more ... Create playlist. Track. Party at the Mansion Original
# Mix. Add to queue. Add to playlist. $1.69. Link: Embed: Artists: Horchata. Length:4:31. Released:2024-06-16. BPM:
# 104. Key ...
#
# [Party at The Mansion - YouTube](https://www.youtube.com/watch?v=NCCBK0fAFZ4)
# If playback doesn't begin shortly, try restarting your device. Up next. Live. Upcoming. Cancel Play Now. Orange
# Grove Hotel & Gardens
#
# [Party at the Mystery Mansion - Mario Party Superstars OST Extended](https://www.youtube.com/watch?v=F5fi28l8_K8)
# Playlist: https://www.youtube.com/playlist?list=PLon7aIPHE1QR7M4RHyU8C9E6I_e6BLQVePlays when the player dances with
# Boo to turn the board to daytime in Horro...
#
# [Playboy - Meth & Red: How To Throw A Party At The Playboy
# Mansion](https://archive.org/details/meth-red-how-to-throw-a-party-at-the-playboy-mansion)
# The Dynamic Duo, Funk Doc and Mr. Meth explore the mansion grounds, referee a skins vs. skins tennis match, hot box
# chronic in the sauna, get down in the grotto, and instigate a Jell-O wrestling tournament between some of the
# ladies at the ultimate Playboy Mansion party. Watch old school meet new school in this freaky-deaky comedy!
#
# Out: None
# [Step 2: Duration 4.58 seconds| Input tokens: 5,595 | Output tokens: 237]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   final_answer("WAYNE MANOR OFFICIAL PLAYLIST on Spotify is a good recommendation for a party at Wayne's mansion.
#   It's a rock/blues playlist potentially suitable for Bruce Wayne.")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Out - Final answer: WAYNE MANOR OFFICIAL PLAYLIST on Spotify is a good recommendation for a party at Wayne's
# mansion. It's a rock/blues playlist potentially suitable for Bruce Wayne.
# [Step 3: Duration 1.93 seconds| Input tokens: 10,984 | Output tokens: 396]
# "WAYNE MANOR OFFICIAL PLAYLIST on Spotify is a good recommendation for a party at Wayne's mansion. It's a rock/blues playlist potentially suitable for Bruce Wayne."

# %% [markdown]
# When you run this example, the output will **display a trace of the workflow steps being executed**. It will also print the corresponding Python code with the message:
#
# ```python
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   results = web_search(query="best music for a Batman party")
#   print(results)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ```
#
# After a few steps, you'll see the generated playlist that Alfred can use for the party! 🎵

# %% [markdown]
# ## Using a Custom Tool to Prepare the Menu
#
# Now that we have selected a playlist, we need to organize the menu for the guests. Again, Alfred can take advantage of `smolagents` to do so. Here, we use the `@tool` decorator to define a custom function that acts as a tool. We'll cover tool creation in more detail later, so for now, we can simply run the code.
#
# As you can see in the example below, we will create a tool using `@tool` decorator and include it in the `tools` list.

# %%
from smolagents import CodeAgent, tool

@tool
def suggest_menu(occasion: str) -> str:
    """
    Suggests a menu based on the occasion.
    Args:
        occasion (str): The type of occasion for the party. Allowed values are:
                - "casual": Menu for casual party.
                - "formal": Menu for formal party.
                - "superhero": Menu for superhero party.
                - "custom": Custom menu.
    """
    if occasion == "casual":
        return "Pizza, snacks, and drinks."
    elif occasion == "formal":
        return "3-course dinner with wine and dessert."
    elif occasion == "superhero":
        return "Buffet with high-energy and healthy food."
    else:
        return "Custom menu for the butler."

agent = CodeAgent(tools=[suggest_menu], model=gemini_model)

agent.run("Prepare a formal menu for the party. Give me detailed breakdown for each course.")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Prepare a formal menu for the party. Give me detailed breakdown for each course.                                │
# │                                                                                                                 │
# ╰─ LiteLLMModel - gemini/gemini-2.0-flash ────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   menu = suggest_menu(occasion="formal")
#   print(menu)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# 3-course dinner with wine and dessert.
#
# Out: None
# [Step 1: Duration 0.85 seconds| Input tokens: 2,248 | Output tokens: 56]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   print("Formal Menu:")
#   print("Appetizer: Seared Scallops with Lemon Butter Sauce - Fresh scallops seared to perfection, served with a
#   light and tangy lemon butter sauce. Garnished with microgreens.")
#   print("Main Course: Filet Mignon with Red Wine Reduction - Tender filet mignon cooked to your preference,
#   accompanied by a rich red wine reduction. Served with asparagus and roasted potatoes.")
#   print("Dessert: Chocolate Lava Cake with Raspberry Coulis - Warm chocolate lava cake with a molten center,
#   drizzled with a sweet and tart raspberry coulis. Served with a scoop of vanilla ice cream.")
#   print("Wine Pairing: Cabernet Sauvignon - A full-bodied red wine that complements the filet mignon and enhances
#   the overall dining experience.")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Formal Menu:
# Appetizer: Seared Scallops with Lemon Butter Sauce - Fresh scallops seared to perfection, served with a light and
# tangy lemon butter sauce. Garnished with microgreens.
# Main Course: Filet Mignon with Red Wine Reduction - Tender filet mignon cooked to your preference, accompanied by a
# rich red wine reduction. Served with asparagus and roasted potatoes.
# Dessert: Chocolate Lava Cake with Raspberry Coulis - Warm chocolate lava cake with a molten center, drizzled with a
# sweet and tart raspberry coulis. Served with a scoop of vanilla ice cream.
# Wine Pairing: Cabernet Sauvignon - A full-bodied red wine that complements the filet mignon and enhances the
# overall dining experience.
#
# Out: None
# [Step 2: Duration 1.63 seconds| Input tokens: 4,635 | Output tokens: 251]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   final_answer("Formal Menu:\nAppetizer: Seared Scallops with Lemon Butter Sauce - Fresh scallops seared to
#   perfection, served with a light and tangy lemon butter sauce. Garnished with microgreens.\nMain Course: Filet
#   Mignon with Red Wine Reduction - Tender filet mignon cooked to your preference, accompanied by a rich red wine
#   reduction. Served with asparagus and roasted potatoes.\nDessert: Chocolate Lava Cake with Raspberry Coulis -
#   Warm chocolate lava cake with a molten center, drizzled with a sweet and tart raspberry coulis. Served with a
#   scoop of vanilla ice cream.\nWine Pairing: Cabernet Sauvignon - A full-bodied red wine that complements the
#   filet mignon and enhances the overall dining experience.")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Out - Final answer: Formal Menu:
# Appetizer: Seared Scallops with Lemon Butter Sauce - Fresh scallops seared to perfection, served with a light and
# tangy lemon butter sauce. Garnished with microgreens.
# Main Course: Filet Mignon with Red Wine Reduction - Tender filet mignon cooked to your preference, accompanied by a
# rich red wine reduction. Served with asparagus and roasted potatoes.
# Dessert: Chocolate Lava Cake with Raspberry Coulis - Warm chocolate lava cake with a molten center, drizzled with a
# sweet and tart raspberry coulis. Served with a scoop of vanilla ice cream.
# Wine Pairing: Cabernet Sauvignon - A full-bodied red wine that complements the filet mignon and enhances the
# overall dining experience.
# [Step 3: Duration 1.43 seconds| Input tokens: 7,573 | Output tokens: 432]
# 'Formal Menu:\nAppetizer: Seared Scallops with Lemon Butter Sauce - Fresh scallops seared to perfection, served with a light and tangy lemon butter sauce. Garnished with microgreens.\nMain Course: Filet Mignon with Red Wine Reduction - Tender filet mignon cooked to your preference, accompanied by a rich red wine reduction. Served with asparagus and roasted potatoes.\nDessert: Chocolate Lava Cake with Raspberry Coulis - Warm chocolate lava cake with a molten center, drizzled with a sweet and tart raspberry coulis. Served with a scoop of vanilla ice cream.\nWine Pairing: Cabernet Sauvignon - A full-bodied red wine that complements the filet mignon and enhances the overall dining experience.'

# %% [markdown]
# The agent will run for a few steps until finding the answer.
#
# The menu is ready! 🥗

# %% [markdown]
# ## Using Python Imports Inside the Agent
#
# We have the playlist and menu ready, but we need to check one more crucial detail: preparation time!
#
# Alfred needs to calculate when everything would be ready if he started preparing now, in case they need assistance from other superheroes.
#
# `smolagents` specializes in agents that write and execute Python code snippets, offering sandboxed execution for security. It supports both open-source and proprietary language models, making it adaptable to various development environments.
#
# **Code execution has strict security measures** - imports outside a predefined safe list are blocked by default. However, you can authorize additional imports by passing them as strings in `additional_authorized_imports`.
# For more details on secure code execution, see the official [guide](https://huggingface.co/docs/smolagents/tutorials/secure_code_execution).
#
# When creating the agent, we ill use `additional_authorized_imports` to allow for importing the `datetime` module.

# %%
from smolagents import CodeAgent
import numpy as np
import time
import datetime

agent = CodeAgent(tools=[], model=gemini_model, additional_authorized_imports=['datetime'])

agent.run(
    """
    Alfred needs to prepare for the party. Here are the tasks:
    1. Prepare the drinks - 30 minutes
    2. Decorate the mansion - 60 minutes
    3. Set up the menu - 45 minutes
    3. Prepare the music and playlist - 45 minutes

    If we start right now, at what time will the party be ready?
    """
)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Alfred needs to prepare for the party. Here are the tasks:                                                      │
# │     1. Prepare the drinks - 30 minutes                                                                          │
# │     2. Decorate the mansion - 60 minutes                                                                        │
# │     3. Set up the menu - 45 minutes                                                                             │
# │     3. Prepare the music and playlist - 45 minutes                                                              │
# │                                                                                                                 │
# │     If we start right now, at what time will the party be ready?                                                │
# │                                                                                                                 │
# ╰─ LiteLLMModel - gemini/gemini-2.0-flash ────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import datetime
#
#   tasks = {
#       "Prepare the drinks": 30,
#       "Decorate the mansion": 60,
#       "Set up the menu": 45,
#       "Prepare the music and playlist": 45
#   }
#
#   total_time = sum(tasks.values())
#   print(f"Total time: {total_time} minutes")
#
#   current_time = datetime.datetime.now()
#   print(f"Current time: {current_time}")
#
#   party_ready_time = current_time + datetime.timedelta(minutes=total_time)
#   print(f"Party ready time: {party_ready_time}")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Total time: 180 minutes
# Current time: 2025-04-24 14:50:28.768032
# Party ready time: 2025-04-24 17:50:28.768032
#
# Out: None
# [Step 1: Duration 1.86 seconds| Input tokens: 2,233 | Output tokens: 186]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   party_ready_time = datetime.datetime.now() + datetime.timedelta(minutes=180)
#   final_answer(party_ready_time)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Out - Final answer: 2025-04-24 17:50:29.836201
# [Step 2: Duration 1.07 seconds| Input tokens: 4,936 | Output tokens: 256]
# datetime.datetime(2025, 4, 24, 17, 50, 29, 836201)

# %% [markdown]
# These examples are just the beginning of what you can do with code agents, and we're already starting to see their utility for preparing the party.
# You can learn more about how to build code agents in the [smolagents documentation](https://huggingface.co/docs/smolagents).
#
# `smolagents` specializes in agents that write and execute Python code snippets, offering sandboxed execution for security. It supports both open-source and proprietary language models, making it adaptable to various development environments.

# %% [markdown]
# ## Sharing Our Custom Party Preparator Agent to the Hub
#
# Wouldn't it be **amazing to share our very own Alfred agent with the community**? By doing so, anyone can easily download and use the agent directly from the Hub, bringing the ultimate party planner of Gotham to their fingertips! Let's make it happen! 🎉
#
# The `smolagents` library makes this possible by allowing you to share a complete agent with the community and download others for immediate use. It's as simple as the following:

# %%
from smolagents import CodeAgent, DuckDuckGoSearchTool, HfApiModel, VisitWebpageTool, FinalAnswerTool, Tool, tool

@tool
def suggest_menu(occasion: str) -> str:
    """
    Suggests a menu based on the occasion.
    Args:
        occasion: The type of occasion for the party.
    """
    if occasion == "casual":
        return "Pizza, snacks, and drinks."
    elif occasion == "formal":
        return "3-course dinner with wine and dessert."
    elif occasion == "superhero":
        return "Buffet with high-energy and healthy food."
    else:
        return "Custom menu for the butler."

@tool
def catering_service_tool(query: str) -> str:
    """
    This tool returns the highest-rated catering service in Gotham City.

    Args:
        query: A search term for finding catering services.
    """
    # Example list of catering services and their ratings
    services = {
        "Gotham Catering Co.": 4.9,
        "Wayne Manor Catering": 4.8,
        "Gotham City Events": 4.7,
    }

    # Find the highest rated catering service (simulating search query filtering)
    best_service = max(services, key=services.get)

    return best_service

class SuperheroPartyThemeTool(Tool):
    name = "superhero_party_theme_generator"
    description = """
    This tool suggests creative superhero-themed party ideas based on a category.
    It returns a unique party theme idea."""

    inputs = {
        "category": {
            "type": "string",
            "description": "The type of superhero party (e.g., 'classic heroes', 'villain masquerade', 'futuristic Gotham').",
        }
    }

    output_type = "string"

    def forward(self, category: str):
        themes = {
            "classic heroes": "Justice League Gala: Guests come dressed as their favorite DC heroes with themed cocktails like 'The Kryptonite Punch'.",
            "villain masquerade": "Gotham Rogues' Ball: A mysterious masquerade where guests dress as classic Batman villains.",
            "futuristic Gotham": "Neo-Gotham Night: A cyberpunk-style party inspired by Batman Beyond, with neon decorations and futuristic gadgets."
        }

        return themes.get(category.lower(), "Themed party idea not found. Try 'classic heroes', 'villain masquerade', or 'futuristic Gotham'.")


# Alfred, the butler, preparing the menu for the party
agent = CodeAgent(
    tools=[
        DuckDuckGoSearchTool(),
        VisitWebpageTool(),
        suggest_menu,
        catering_service_tool,
        SuperheroPartyThemeTool()
        ],
    model=gemini_model,
    max_steps=10,
    verbosity_level=2
)

agent.run("Give me best playlist for a party at the Wayne's mansion. The party idea is a 'villain masquerade' theme")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Give me best playlist for a party at the Wayne's mansion. The party idea is a 'villain masquerade' theme        │
# │                                                                                                                 │
# ╰─ LiteLLMModel - gemini/gemini-2.0-flash ────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Output message of the LLM: ────────────────────────────────────────────────────────────────────────────────────────
# Thought: I need to find a playlist suitable for a villain masquerade party at Wayne's mansion. Since I don't have a
# tool that directly generates playlists, I'll use web search to find existing playlists that fit the theme, and then
# select the best one based on the results.
# Code:
# ```py
# query = "villain masquerade party playlist"
# search_results = web_search(query=query)
# print(search_results)
# ```<end_code>
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   query = "villain masquerade party playlist"
#   search_results = web_search(query=query)
#   print(search_results)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [dancing with the villain during a masquerade ball - playlist ... -
# Spotify](https://open.spotify.com/playlist/17SEJ9K7DyEAhgoJgZlyNN)
# mkisay · Playlist · 40 songs · 33 likes
#
# [you're at a masquerade and unknowingly dancing with your ... -
# YouTube](https://www.youtube.com/watch?v=e1ic7bV9dtA)
# ahh I literally couldn't wait to post this, so here is an upload a day early!! lets be honest, we come here for the
# music and stay for the povs. I totally di...
#
# [dancing with your enemy at a masquerade ball - playlist by ... -
# Spotify](https://open.spotify.com/playlist/0zNqQEIlXMRKi3bBgccKWv)
# Playlist · dancing with your enemy at a masquerade ball · 25 items · 8.9K likes. ... Playlist · dancing with your
# enemy at a masquerade ball · 25 items · 8.9K likes. Playlist · martika 🎧 · 25 items · 8.9K likes. Sign up Log in.
# Resize main navigation. Loading. Company. About Jobs For the Record ...
#
# [Villain Party Playlist to Boost Your Confidence ️‍ ... - YouTube](https://www.youtube.com/watch?v=cW2tfICi7yc)
# Welcome to my Hype Mix ️‍🔥 Let's get down and dirty this week and party it up 💃🏼!! I hope this playlist brings you a
# Confidence Boost and get you ready t...
#
# [Masquerade Ball Party | Best in 2025 - Classpop](https://www.classpop.com/magazine/masquerade-ball-party)
# Superheroes and villains; Black and white; Roaring '20s; Angels and demons ... Music is a must. Even if you're not
# going with an all-out ball gown bash theme, you'll want to have a great playlist. For a traditional period, go with
# classical music like Vivaldi, Strauss, Beethoven or Mozart. ... While costumes are not necessarily required ...
#
# [Masquerade party music - playlist by drew - Spotify](https://open.spotify.com/playlist/3gICKSayCeN6muUWNGHeK4)
# Playlist · Masquerade party music 🎭 · 38 items · 8 saves
#
# [Best villains Songs Lists for DJs: Your Complete contemporary Playlist
# ...](https://stagebibles.com/best-songs-for-villains/)
# If you're looking for the best villains music or throwing a party, these are songs you'll want to include. We
# rounded up the best villains songs to build the ultimate Playlist. ... Your Complete stylish Playlist. Best text
# lyrics prank Songs Lists for MCs: Your Complete 21st-Century Listing.
#
# ["Unleash The Darkness: 10 Songs That Define The Perfect Villain
# Playlist"](https://theawakenbuddha.com/best-10-villain-song-unleash-darkness-playlist/)
# Creating the perfect villain playlist requires a mix of intensity, mystery, and power-packed tunes. Here's a list
# of 10 songs that embody the essence of a cinematic villain, perfect for setting the mood for dark and dramatic
# vibes.
#
# [Waltzing with your nemesis in a masquerade ball (dark royalty core
# ...](https://www.youtube.com/watch?v=TaBYkXakN6s)
# ⤍ 00:00 𝐌𝐚𝐬𝐪𝐮𝐞𝐫𝐚𝐝𝐞 𝐨𝐟 𝐭𝐡𝐞 𝐯𝐚𝐦𝐩𝐢𝐫𝐞𝐬 https://youtu.be/W308Gr5RHVE⤍ 03:35 ...
#
# [The 99 Best Songs for Villains (Our Villain Arc Playlist) -
# iSpyTunes](https://www.ispytunes.com/post/best-songs-for-villains)
# With our handpicked villain playlist with 99 of the best songs, we invite you to immerse yourself in the world of
# darkness, power, and redemption. Whether you are a storyteller seeking inspiration or a listener looking for an
# exhilarating musical experience, this playlist offers a journey into the minds and hearts of a villain.
#
# Out: None
# [Step 1: Duration 2.37 seconds| Input tokens: 2,464 | Output tokens: 96]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Output message of the LLM: ────────────────────────────────────────────────────────────────────────────────────────
# Thought: Based on the search results, there are several Spotify and YouTube playlists that seem promising. I will
# now visit a few of these links to get a better understanding of the songs included in those playlists and make a
# decision of which would be best for Wayne's Mansion villain masquerade. Let's start by visiting the Spotify
# playlist "dancing with your enemy at a masquerade ball".
# Code:
# ```py
# playlist_url = "https://open.spotify.com/playlist/0zNqQEIlXMRKi3bBgccKWv"
# playlist_content = visit_webpage(url=playlist_url)
# print(playlist_content)
# ```<end_code>
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   playlist_url = "https://open.spotify.com/playlist/0zNqQEIlXMRKi3bBgccKWv"
#   playlist_content = visit_webpage(url=playlist_url)
#   print(playlist_content)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# dancing with your enemy at a masquerade ball - playlist by martika 🎧 | Spotify
#
# ![](https://image-cdn-ak.spotifycdn.com/image/ab67706c0000da84c60ab37a0a068d818587e23e)
#
# dancing with your enemy at a masquerade ball
# ============================================
#
# tags: slow burn, dark academia, enemies to lovers
#
# ![](https://i.scdn.co/image/ab6775700000ee857092c3052f5a5cfde1a4f1cd)
#
# [martika 🎧](/user/mariademelooo)
#
# 8,708 saves1 hr 28 min
#
# ![](https://i.scdn.co/image/ab67616d000048512f8d9427fea9dd36a4fb4f1b)
#
# [Overture - From 'The Phantom Of The Opera' Motion Picture](/track/7o3DV1szMH5Fd38f1QwgPO)
#
# Andrew Lloyd Webber
#
# ![](https://i.scdn.co/image/ab67616d00004851816ebc03f57f321bf42cb308)
#
# [Serenade for Strings in E Major, Op. 22, B. 52: II. Tempo di valse](/track/3sAYxq1986j3ydqLv6jwUJ)
#
# Antonín Dvořák, Prague Chamber Orchestra, Petr Skvor
#
# ![](https://i.scdn.co/image/ab67616d00004851d7fb3e4c63020039d1cff6b2)
#
# [Young And Beautiful](/track/2nMeu6UenVvwUktBCpLMK9)
#
# Lana Del Rey
#
# ![](https://i.scdn.co/image/ab67616d000048516e7bb273ff9cb1de1e1d4d0a)
#
# [Clair de Lune, L. 32](/track/5u5aVJKjSMJr4zesMPz7bL)
#
# Claude Debussy, Martin Jones
#
# ![](https://i.scdn.co/image/ab67616d00004851bd1ed4346fa2740ea3c66cb5)
#
# [Devil's Backbone](/track/4qoD4IJbbir3hsAu4IowiG)
#
# The Civil Wars
#
# ![](https://i.scdn.co/image/ab67616d0000485185f7ebb70da4cdcf02cb5630)
#
# [So This Is Love: Waltz](/track/2r1BzMa2YFYt4BEBwL3vx1)
#
# Mack David, Al Hoffman, Jerry Livingston
#
# ![](https://i.scdn.co/image/ab67616d000048518af0e6e8cd90c28749ccbcd9)
#
# [Romeo and Juliet, Op. 64 / Act 1: Dance Of The Knights](/track/2LiWNkeUOAeibGxJKxmjsD)
#
# Sergei Prokofiev, The Cleveland Orchestra, Lorin Maazel
#
# ![](https://i.scdn.co/image/ab67616d000048510bdf4dd39843ad48c5b66bc4)
#
# [Mia & Sebastian’s Theme](/track/1Vk4yRsz0iBzDiZEoFMQyv)
#
# Justin Hurwitz
#
# ![](https://i.scdn.co/image/ab67616d000048517704ae7ab27d875a9f407e44)
#
# [Merry-Go-Round of Life (From Howl's Moving Castle Original Soundtrack) - Live
# (Remastered)](/track/1R8h6rhCVAs8kEL6rkc1ZI)
#
# Nuvo Orchestra
#
# ![](https://i.scdn.co/image/ab67616d000048510b4f0565f8a790f5105aeb1c)
#
# [I Wanna Be Yours](/track/0ryEyJ994SqdJwGJXyS1SF)
#
# Arctic Monkeys
#
# ![](https://i.scdn.co/image/ab67616d0000485165c6c451e1ed0d70f0774b24)
#
# [La Valse de L'Amour](/track/0BNQdhKugKzoezQVkHB1TA)
#
# Patrick Doyle
#
# ![](https://i.scdn.co/image/ab67616d000048512b62f79949ec100b29c04b00)
#
# [Skyfall](/track/3mr584ZFSkZrWja9kJAzlb)
#
# Adele
#
# ![](https://i.scdn.co/image/ab67616d0000485133f38cff21d83cf63e15ad5f)
#
# [War of Hearts (Acoustic Version)](/track/2aJWkpCXMvIIZISkMQr1lE)
#
# Ruelle
#
# ![](https://i.scdn.co/image/ab67616d000048518265a736a1eb838ad5a0b921)
#
# [Afraid](/track/7brQHA2CgQpcMBiOlfiXYb)
#
# The Neighbourhood
#
# ![](https://i.scdn.co/image/ab67616d000048517504ee710566d200dfee77b0)
#
# [Bella's Lullaby (From "Twilight")](/track/0w5ymU3obTE6hVDfMHJDDL)
#
# Carter Burwell, Maksym Rzemiński
#
# ![](https://i.scdn.co/image/ab67616d0000485186c35c057f1d76baefa1b2f5)
#
# [Amur Waves](/track/4iLKAdJtlTGdZGkHIdYEB0)
#
# Max Kyuss, Nikolai Nazarov, Separate Exemplary Orchestra of USSR Defense Ministry
#
# ![](https://i.scdn.co/image/ab67616d000048512a447f736fe14eb81dd6e615)
#
# [The Second Waltz](/track/2vHzTlwAX8RACAZs7bNnvj)
#
# André Rieu, Johann Strauss Orchestra, Dmitri Shostakovich
#
# ![](https://i.scdn.co/image/ab67616d00004851956ad452bae3e6e742284778)
#
# [Gramofon](/track/019xlq3CAcoYYZVkvL7bnJ)
#
# Symphony Orchestra of the National State Teleradiocompany of the Republic of Belarus
#
# ![](https://i.scdn.co/image/ab67616d000048511d9c6602aa95abd8c5b146da)
#
# [Tchaikovsky: Swan Lake, Op. 20, Act 2: No. 10, Scene. Moderato](/track/2xizRhme7pYeITbH1NLLGt)
#
# Pyotr Ilyich Tchaikovsky, André Previn, London Symphony Orchestra
#
# ![](https://i.scdn.co/image/ab67616d000048510fe8bc522921dc5eeccdb50d)
#
# [My Blood](/track/6knYNyQupBIbBxV8TMOMYM)
#
# Ellie Goulding
#
# ![](https://i.scdn.co/image/ab67616d000048518231fcd4320c2bf61cdb5d88)
#
# [Masquerade Suite: Waltz](/track/1WBagB7FdOlxUpYTG9XVik)
#
# Aram Khachaturian, St. Petersburg State Symphony Orchestra, Andre Anichanov
#
# ![](https://i.scdn.co/image/ab67616d0000485186c35c057f1d76baefa1b2f5)
#
# [Blue Night](/track/0Xbbyit5BaEz3h6CxjJgi5)
#
# Vasiliy Agapkin, Nikolai Nazarov, Separate Exemplary Orchestra of USSR Defense Ministry
#
# ![](https://i.scdn.co/image/ab67616d00004851fb4aac6e97e78983ac5f6280)
#
# [Reflections](/track/5Zf25eS8E1znm9mez4cGsm)
#
# Toshifumi Hinata
#
# ![](https://i.scdn.co/image/ab67616d000048515e02f2f639b9008f4d1935d3)
#
# [I Put A Spell On You (Fifty Shades of Grey) - From "Fifty Shades Of Grey"
# Soundtrack](/track/6HChE1b3T5ke2XA50t9kGd)
#
# Annie Lennox
#
# ![](https://i.scdn.co/image/ab67616d000048516c8ef0538e04f2e28380dcc5)
#
# [Experience](/track/1BncfTJAWxrsxyT9culBrj)
#
# Ludovico Einaudi, Daniel Hope, I Virtuosi Italiani
#
# Out: None
# [Step 2: Duration 2.80 seconds| Input tokens: 6,028 | Output tokens: 235]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Output message of the LLM: ────────────────────────────────────────────────────────────────────────────────────────
# Thought: The playlist "dancing with your enemy at a masquerade ball" has a mix of classical and modern songs,
# including some songs with dark themes, which could be fitting for a villain masquerade. It includes tracks like
# "Overture - From 'The Phantom Of The Opera'", "Devil's Backbone", "Romeo and Juliet: Dance Of The Knights",
# "Skyfall", and "I Put A Spell On You". It also features more romantic songs like "Young and Beautiful" and "La
# Valse de L'Amour". Overall it seems fitting.
#
# Let's check the "dancing with the villain during a masquerade ball" playlist from Spotify as well.
# Code:
# ```py
# playlist_url = "https://open.spotify.com/playlist/17SEJ9K7DyEAhgoJgZlyNN"
# playlist_content = visit_webpage(url=playlist_url)
# print(playlist_content)
# ```<end_code>
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   playlist_url = "https://open.spotify.com/playlist/17SEJ9K7DyEAhgoJgZlyNN"
#   playlist_content = visit_webpage(url=playlist_url)
#   print(playlist_content)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# dancing with the villain during a masquerade ball - playlist by mkisay | Spotify
#
# ![](https://image-cdn-ak.spotifycdn.com/image/ab67706c0000da84b6f19b197d15ea0388d4b2be)
#
# dancing with the villain during a masquerade ball
# =================================================
#
# slowly the dance becomes less about keeping the other out of trouble and more about staying in each others embrace
#
# ![](https://i.scdn.co/image/ab6775700000ee8549602817cbabf5889f9ddd89)
#
# [mkisay](/user/yasikm123)
#
# 32 saves
#
# ![](https://i.scdn.co/image/ab67616d000048515a34d11f1846ee4387b73ff3)
#
# [Valse sentimentale, Op. 51, No. 6](/track/2hNhsPZVVOr0SOqShooaEJ)
#
# Pyotr Ilyich Tchaikovsky, Josef Sakonov, London Festival Orchestra
#
# ![](https://i.scdn.co/image/ab67616d000048514cf0b29eb06a92aa96acae64)
#
# [Mellohi](/track/4gJWOPtNwTZOZNbAMMAK4m)
#
# C418
#
# ![](https://i.scdn.co/image/ab67616d00004851ac94eec5d5469a0e533c8af0)
#
# [Masquerade (Suite): 1. Waltz - Excerpt](/track/0FyAT4nUMZWJmAI1Qov1Zj)
#
# Aram Khachaturian, London Symphony Orchestra, Stanley Black
#
# ![](https://i.scdn.co/image/ab67616d000048512784770ffde81f961730f4f7)
#
# [Marche slave, Op. 31, TH 45](/track/4L9io4XpkeysnBBbn6VH3r)
#
# Pyotr Ilyich Tchaikovsky, Russian National Orchestra, Mikhail Pletnev
#
# ![](https://i.scdn.co/image/ab67616d000048519f3afba678d78dc6ed799e20)
#
# [Introitus](/track/0E6QVfj9FcdDOgX5CFsj4k)
#
# Wolfgang Amadeus Mozart, Lisa Beckley, Elena Filipova, Magdaléna Hajóssyová, Peter Mikulas, Michel Piquemal, Gloria
# Scalchi, Michel Piquemal Vocal Ensemble, Hungarian State Opera Chorus, Oxford Schola Cantorum
#
# ![](https://i.scdn.co/image/ab67616d00004851a10dae009613dad4808065fb)
#
# [Der Erlkönig](/track/1Hz6nOTVdBAxtlgac8s8jb)
#
# The Vienna Chamber Ensemble
#
# ![](https://i.scdn.co/image/ab67616d0000485126484a82dfe0550d290fafbb)
#
# [IV. Allegro con fuoco](/track/6JxJH8TbKzTc4CSagIEhiH)
#
# Antonín Dvořák, Leonard Bernstein, New York Philharmonic
#
# ![](https://i.scdn.co/image/ab67616d000048519f3afba678d78dc6ed799e20)
#
# [Lacrimosa](/track/1UvaZaHkh3D9AkmBrrnbFg)
#
# Wolfgang Amadeus Mozart, Lisa Beckley, Elena Filipova, Magdaléna Hajóssyová, Peter Mikulas, Michel Piquemal, Gloria
# Scalchi, Michel Piquemal Vocal Ensemble, Hungarian State Opera Chorus, Oxford Schola Cantorum
#
# ![](https://i.scdn.co/image/ab67616d0000485113e450fd3a53964a8927641e)
#
# [String Sextet in D Minor, Op. 70, "Souvenir de Florence": I. Allegro con spirito](/track/72jIJDADnBLJKXV2yxv5N0)
#
# Pyotr Ilyich Tchaikovsky, Jan Vogler
#
# ![](https://i.scdn.co/image/ab67616d00004851f81386e028bea545388c7139)
#
# [Egmont](/track/6jSZUUFAlSpQzG8Iu665UO)
#
# Bert Appermont, Sande Musikkorps
#
# ![](https://i.scdn.co/image/ab67616d00004851b177a0e8e299facc7fd9e637)
#
# [Moonlight Sonata (3rd Movement)](/track/7wyOeWMb8aiR2qjdCEEYZJ)
#
# Junior dos Santos Silva
#
# ![](https://i.scdn.co/image/ab67616d0000485134e12499245114cbda2c5a95)
#
# [Concerto In G Minor "L'estate", Op. 8, No. 2, RV 315: III. Presto](/track/3UKSZtDT4Mwsjw1M5aGSk8)
#
# Antonio Vivaldi, Nadja Salerno-Sonnenberg, Orchestra of St. Luke's
#
# ![](https://i.scdn.co/image/ab67616d0000485134e12499245114cbda2c5a95)
#
# [Concerto In F Minor "L'inverno", Op. 8, No. 4, RV 297: III. Allegro](/track/14juZTNtGMjtKau0sbNUrC)
#
# Antonio Vivaldi, Nadja Salerno-Sonnenberg, Orchestra of St. Luke's
#
# ![](https://i.scdn.co/image/ab67616d000048513236c34778c561e8114df05f)
#
# [Egmont: II. Filips and Egmont](/track/4LdyMRalf9mGWWMQO1joTZ)
#
# Bert Appermont, North Rhine Westphalia Youth Band, Pierre Kuijpers
#
# ![](https://i.scdn.co/image/ab67616d00004851577bb481664d06b0b5d5ba58)
#
# [The Four Seasons: Concerto No. 4 in F Minor, RV 297 "L'inverno" (winter): I. Allegro non
# molto](/track/0ROMalDdNg3L2HoZP4qFyJ)
#
# Antonio Vivaldi, Adrian Chandler, La Serenissima
#
# ![](https://i.scdn.co/image/ab67616d0000485182700342372d016a0a7d3a8c)
#
# [Requiem in D minor, K.626: 3. Sequentia: Lacrimosa](/track/4ATc4is1rQb7PgKqtOdDnR)
#
# Wolfgang Amadeus Mozart, The Monteverdi Choir, English Baroque Soloists, John Eliot Gardiner
#
# ![](https://i.scdn.co/image/ab67616d00004851d612003e37c4cdc82f39eda7)
#
# [Paganini: 24 Caprices, Op. 1: No. 24 in A Minor](/track/6cC6h5E351deEGFd7Kh9uy)
#
# Niccolò Paganini, Itzhak Perlman
#
# ![](https://i.scdn.co/image/ab67616d00004851d2ca535155e882ce82de1feb)
#
# [21 Hungarian Dances, WoO 1: Hungarian Dance No. 5 in G Minor. Allegro (Orch.
# Schmeling)](/track/2oLjhx7w8Hyd3gry9cCXr7)
#
# Johannes Brahms, Wiener Philharmoniker, Claudio Abbado
#
# ![](https://i.scdn.co/image/ab67616d00004851cb58407c5c70d9a0dafe8534)
#
# [Introduction and Rondo capriccioso in A Minor](/track/37oIGXkiR4MlM79w65rd02)
#
# Camille Saint-Saëns, Dong-Suk Kang, Polish National Radio Symphony Orchestra, Antoni Wit
#
# ![](https://i.scdn.co/image/ab67616d000048516e92095455d289f8c6f5159e)
#
# [Danse macabre in G Minor, Op. 40](/track/1IM8x4lxZVOOP9gpQD6c5s)
#
# Camille Saint-Saëns, Slovak Radio Symphony Orchestra, Keith Clark
#
# ![](https://i.scdn.co/image/ab67616d00004851db9e28e966b913fae3510c01)
#
# [Symphony No. 7 in A, Op. 92: 2. Allegretto](/track/7zZYnegwVYSsoqCdtSswfi)
#
# Ludwig van Beethoven, London Symphony Orchestra, Antal Doráti
#
# ![](https://i.scdn.co/image/ab67616d00004851c97bf8f2fd455309e3af1411)
#
# [Symphony No. 7 in A Major, Op. 92: II. Allegretto - 2018 Remastered Version](/track/71MTc0M9a6QaJwFu5DvmQv)
#
# Ludwig van Beethoven, George Szell, The Cleveland Orchestra
#
# ![](https://i.scdn.co/image/ab67616d00004851e710f20b11e91bef5b0d1c5b)
#
# [On the Hills of Manchuria [Na sopkah Manchzhurii]](/track/0nA2E4hX7clVxmlPWPv1UJ)
#
# Russian Brass Band
#
# ![](https://i.scdn.co/image/ab67616d00004851753a25c2cf1be4e0ac045a00)
#
# [Symphony No. 9 in E Minor, Op. 95, B. 178 "From the New World": IV. Allegro con
# fuoco](/track/6nqHzwOdGIaX57U6VU6kMO)
#
# Antonín Dvořák, Wiener Philharmoniker, Herbert von Karajan
#
# ![](https://i.scdn.co/image/ab67616d00004851577bb481664d06b0b5d5ba58)
#
# [The Four Seasons: Concerto No. 2 in G Minor, RV 315 "L'estate" (summer): I. Allegro non molto –
# Allegro](/track/61TeCsBeZZrH4IDr9yIvoj)
#
# Antonio Vivaldi, Adrian Chandler, La Serenissima
#
# ![](https://i.scdn.co/image/ab67616d00004851f794e5702e282befe2c39c85)
#
# [Vivaldi: La stravaganza, Violin Concerto in E Minor, Op. 4 No. 2, RV 279: I.
# Allegro](/track/6FIES8iEfuZ6KUQMOs2T92)
#
# Antonio Vivaldi, Europa Galante, Fabio Biondi
#
# ![](https://i.scdn.co/image/ab67616d00004851b57c6f426e022517133a6872)
#
# [Egmont Overture, Op. 84 - 2018 Remastered Version](/track/1EjfCGPicAauZwnbFrTczK)
#
# Ludwig van Beethoven, George Szell, The Cleveland Orchestra
#
# ![](https://i.scdn.co/image/ab67616d000048519a6298caaf72570fe34be4fc)
#
# [Dance of the goblins](/track/4EHgbiEVdAlh1FDyS79iGp)
#
# Razvan Stoica
#
# ![](https://i.scdn.co/image/ab67616d0000485141191c89dee33d5b7fdfda3c)
#
# [Passacaglia for Violin and Viola](/track/3qpDZxipz329ptcKuQY35i)
#
# Johan Halvorsen, Davide Alogna, José Adolfo Alejo
#
# ![](https://i.scdn.co/image/ab67616d00004851ec9baa40ddbbe51ec0983498)
#
# [Mozart: Lacrimosa from Requiem in D Minor (Arr. For Piano and Voice Quartet)](/track/2VBTUbijSoLw5hPwZ8y3T3)
#
# Daniela Santos
#
# Company
#
# [About](https://www.spotify.com/us/about-us/contact/)[Jobs](https://www.lifeatspotify.com/)[For the
# Record](https://newsroom.spotify.com/)
#
# Communities
#
# [For
# Artists](https://artists.spotify.com/)[Developers](https://developer.spotify.com/)[Advertising](https://ads.spotify
# .com/)[Investors](https://investors.spotify.com/)[Vendors](https://spotifyforvendors.com/)
#
# Useful links
#
# [Support](https://support.spotify.com/)[Free Mobile App](https://www.spotify.com/us/free/)
#
# Spotify Plans
#
# [Premium Individual](https://www.spotify.com/us/premium/#ref=spotifycom_footer_premium_individual)[Premium
# Duo](https://www.spotify.com/us/duo/#ref=spotifycom_footer_premium_duo)[Premium
# Family](https://www.spotify.com/us/family/#ref=spotifycom_footer_premium_family)[Premium
# Student](https://www.spotify.com/us/student/#ref=spotifycom_footer_premium_student)[Spotify
# Free](https://www.spotify.com/us/free/#ref=spotifycom_footer_free)[Audiobooks
# Access](https://www.spotify.com/us/audiobooks/#plans)
#
# ---
#
# [Legal](https://www.spotify.com/us/legal/)
#
# [Safety & Privacy Center](https://www.spotify.com/us/safetyandprivacy/)
#
# [Privacy Policy](https://www.spotify.com/us/legal/privacy-policy/)
#
# [Cookies](https://www.spotify.com/us/legal/cookies-policy/)
#
# [About Ads](https://www.spotify.com/us/legal/privacy-policy/#s3)
#
# [Accessibility](https://www.spotify.com/us/accessibility/)
#
# [Notice at Collection](https://www.spotify.com/us/legal/notice-at-collection/)
#
# Your Privacy ChoicesCalifornia Consumer Privacy Act (CCPA) Opt-Out Icon
#
# © 2025 Spotify AB
#
# English
#
# Choose a languageThis updates what you read on open.spotify.com
#
# EnglishEnglishAfrikaansAfrikaansአማርኛAmharic[العَرَبِيَّةArabic](https://open.spotify.com/playlist/17SEJ9K7DyEAhgoJgZlyNN
# )[عربي مصريArabic (Egypt)](https://open.spotify.com/playlist/17SEJ9K7DyEAhgoJgZlyNN)[العَرَبِيَّة مغربيArabic
# (Morocco)](https://open.spotify.com/playlist/17SEJ9K7DyEAhgoJgZlyNN)[العربية السعوديةArabic (Saudi
# Arabia)](https://open.spotify.com/playlist/17SEJ9K7DyEAhgoJgZlyNN)AzərbaycancaAzerbaijaniБългарскиBulgarianभोजपुरीBhoj
# puriবাংলাBengaliBosanskiBosnianCatalàCatalanČeštinaCzechDanskDanish[DeutschGerman](https://open.spotify.com/playlist/1
# 7SEJ9K7DyEAhgoJgZlyNN)EλληνικάGreekEnglishUnited Kingdom[Español de EspañaEuropean
# Spanish](https://open.spotify.com/playlist/17SEJ9K7DyEAhgoJgZlyNN)[Español de LatinoaméricaLatin American
# Spanish](https://open.spotify.com/playlist/17SEJ9K7DyEAhgoJgZlyNN)[Español (Argentina)Spanish
# (Argentina)](https://open.spotify.com/playlist/17SEJ9K7DyEAhgoJgZlyNN)[Español (México)Spanish
# (Mexico)](https://open.spotify.com/playlist/17SEJ9K7DyEAhgoJgZlyNN)EestiEstonianEuskaraBasqueفارسیPersianSuomeksiFi
# nnishFilipinoFilipino[FrançaisFrench](https://open.spotify.com/playlist/17SEJ9K7DyEAhgoJgZlyNN)[Français
# CanadienCanadian
# French](https://open.spotify.com/playlist/17SEJ9K7DyEAhgoJgZlyNN)GalegoGalicianગુજરાતીGujaratiעבריתHebrewहिन्दीHindiHrvat
# skiCroatianMagyarHungarian[Bahasa
# IndonesiaIndonesian](https://open.spotify.com/playlist/17SEJ9K7DyEAhgoJgZlyNN)ÍslenskaIcelandic[ItalianoItalian](ht
# tps://open.spotify.com/playlist/17SEJ9K7DyEAhgoJgZlyNN)[日本語Japanese](https://open.spotify.com/playlist/17SEJ9K7D
# yEAhgoJgZlyNN)ಕನ್ನಡKannada한국어KoreanLietuviųLithuanianLatviešuLatvianМакедонскиMacedonianമലയാളംMalayalamमराठीMarathiMe
# layuMalayNorskNorwegianनेपालीNepaliNederlandsDutchଓଡ଼ିଆOdiaਪੰਜਾਬੀPunjabiپنجابیPunjabi (Naskh)PolskiPolish[Português do
# BrasilBrazilian Portuguese](https://open.spotify.com/playlist/17SEJ9K7DyEAhgoJgZlyNN)[PortuguêsEuropean
# Portuguese](https://open.spotify.com/playlist/17SEJ9K7DyEAhgoJgZlyNN)RomânăRomanianРусскийRussianSlovenčinaSlovakSl
# ovenskiSlovenianSrpskiSerbianSvenskaSwedishKiswahiliSwahiliதமிழ்TamilతెలుగుTeluguภาษาไทยThai[TürkçeTurkish](https://open
# .spotify.com/playlist/17SEJ9K7DyEAhgoJgZlyNN)УкраїнськаUkrainianاردوUrduTiếng ViệtVietnamese简体中文Simplified
# Chinese繁體中文 (香港)Chinese (Traditional) Hong Kong中文Traditional ChineseIsiZuluZulu
#
# Out: None
# [Step 3: Duration 2.58 seconds| Input tokens: 12,234 | Output tokens: 431]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 4 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Output message of the LLM: ────────────────────────────────────────────────────────────────────────────────────────
# Thought: This playlist is largely classical, featuring composers such as Tchaikovsky, Mozart, Dvorak and Beethoven.
# The description mentions the dance becoming less about keeping the other out of trouble and more about staying in
# each others embrace. This playlist would be more suitable for the waltz/ballroom dancing portion of the masquerade,
# but is missing some modern elements.
#
# Considering the setting is Wayne's mansion, and the theme is a villain masquerade, I think a mix of classical and
# modern would be best. I'll select the first playlist "dancing with your enemy at a masquerade ball" and suggest
# adding some songs from "The 99 Best Songs for Villains" listed in the search results if Bruce Wayne wants a longer
# playlist.
# Code:
# ```py
# final_answer("The best playlist for a villain masquerade party at Wayne's mansion is 'dancing with your enemy at a
# masquerade ball' on Spotify. Consider adding tracks from 'The 99 Best Songs for Villains' for a longer playlist.")
# ```<end_code>
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   final_answer("The best playlist for a villain masquerade party at Wayne's mansion is 'dancing with your enemy
#   at a masquerade ball' on Spotify. Consider adding tracks from 'The 99 Best Songs for Villains' for a longer
#   playlist.")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Out - Final answer: The best playlist for a villain masquerade party at Wayne's mansion is 'dancing with your enemy
# at a masquerade ball' on Spotify. Consider adding tracks from 'The 99 Best Songs for Villains' for a longer
# playlist.
# [Step 4: Duration 2.01 seconds| Input tokens: 23,317 | Output tokens: 638]
# "The best playlist for a villain masquerade party at Wayne's mansion is 'dancing with your enemy at a masquerade ball' on Spotify. Consider adding tracks from 'The 99 Best Songs for Villains' for a longer playlist."

# %%
agent.push_to_hub('hackyroot/AlfredAgent', token=userdata.get("HF_TOKEN_AGENTS"))
# Out:
# README.md:   0%|          | 0.00/387 [00:00<?, ?B/s]
# No files have been modified since last commit. Skipping to prevent empty commit.
# WARNING:huggingface_hub.hf_api:No files have been modified since last commit. Skipping to prevent empty commit.
# This agent has step_callbacks: they will be ignored by this method. 1
# For security reasons, we do not export the `api_key` attribute of your model. Please export it manually.
# CommitInfo(commit_url='https://huggingface.co/spaces/hackyroot/AlfredAgent/commit/e4744ecbefb7f9e8b24aa3456d698bd6c936a9dd', commit_message='Upload agent', commit_description='', oid='e4744ecbefb7f9e8b24aa3456d698bd6c936a9dd', pr_url=None, repo_url=RepoUrl('https://huggingface.co/spaces/hackyroot/AlfredAgent', endpoint='https://huggingface.co', repo_type='space', repo_id='hackyroot/AlfredAgent'), pr_revision=None, pr_num=None)

# %% [markdown]
# To download the agent again, use the code below:

# %%
agent = CodeAgent(tools=[], model=gemini_model)
alfred_agent = agent.from_hub('hackyroot/AlfredAgent', trust_remote_code=True, token=userdata.get('HF_TOKEN_AGENTS'))
# Out:
# Fetching 14 files:   0%|          | 0/14 [00:00<?, ?it/s]

# %%
alfred_agent.model = gemini_model
alfred_agent.run("Give me best playlist for a party at the Wayne's mansion. The party idea is a 'villain masquerade' theme")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Give me best playlist for a party at the Wayne's mansion. The party idea is a 'villain masquerade' theme        │
# │                                                                                                                 │
# ╰─ LiteLLMModel - gemini/gemini-2.0-flash ────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Output message of the LLM: ────────────────────────────────────────────────────────────────────────────────────────
# Thought: I need to suggest a playlist for a villain masquerade party at Wayne's mansion. Since I don't have a tool
# to directly generate playlists, I will use web search to find suitable playlists or songs for a villain-themed
# masquerade party.
# Code:
# ```py
# search_query = "villain masquerade party playlist"
# search_results = web_search(query=search_query)
# print(search_results)
# ```<end_code>
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   search_query = "villain masquerade party playlist"
#   search_results = web_search(query=search_query)
#   print(search_results)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [you're at a masquerade and unknowingly dancing with the
# villain](https://open.spotify.com/playlist/4zxYvQs9gByjRhAn5ujSfQ)
# you're at a masquerade and unknowingly dancing with the villain · Playlist · 89 songs · 10 likes
#
# [you're at a masquerade and unknowingly dancing with your ... - YouTube](https://m.youtube.com/watch?v=e1ic7bV9dtA)
# ahh I literally couldn't wait to post this, so here is an upload a day early!! lets be honest, we come here for the
# music and stay for the povs. I totally di...
#
# [dancing with the villain during a masquerade ball - playlist ... -
# Spotify](https://open.spotify.com/playlist/17SEJ9K7DyEAhgoJgZlyNN)
# mkisay · Playlist · 40 songs · 33 likes
#
# [Villain Party Playlist to Boost Your Confidence ️‍ ... - YouTube](https://m.youtube.com/watch?v=cW2tfICi7yc)
# Welcome to my Hype Mix ️‍🔥 Let's get down and dirty this week and party it up 💃🏼!! I hope this playlist brings you a
# Confidence Boost and get you ready t...
#
# [Masquerade party music - playlist by drew - Spotify](https://open.spotify.com/playlist/3gICKSayCeN6muUWNGHeK4)
# Playlist · Masquerade party music 🎭 · 38 items · 8 saves
#
# [Songs You Need on Your Villain Era Playlist -
# ArtieCarden](https://artiecarden.com/2023/04/10/villain-era-playlist-songs/)
# 3 thoughts on " Songs You Need on Your Villain Era Playlist " Artiecarden says: September 29, 2024 at 6:40 pm.
# you're welcome, i'm glad it helped 🙂 . Like ... 2024 at 3:38 am. Great list! Compiling music for mine and my
# husband's Addams Family Themed vow renewal and party, and also for a Halloween bellydance performance as villain
# ...
#
# [The Villain's Legacy: Darkness and Triumph in Masquerade in
# Darkness,](https://soundcloud.com/seannstein2019/the-villains-legacy-darkness-and-triumph?in=seannstein2019/sets/ma
# squerade-in-darkness)
# You are the villain of this story, my handsome demon, dark satanic witch king, and to our dark princess Eleanor —
# we love you, Seán, and we are so proud of you. One day, you will conquer the land of Alabama — by ambush, by
# surprise. ... Playlists containing The Villain's Legacy: Darkness and Triumph; More tracks like The Villain's
# Legacy ...
#
# [Ultimate Villain Playlist - YouTube
# Music](https://music.youtube.com/playlist?list=PL-BnPF_Yo3_jhVn5cDGvY_zo701QMaZNx)
# A growing collection of Villain Songs, from games, to movies, and from books to comics, not to mention 'What If's'.
#
# [Best villains Songs Lists for DJs: Your Complete contemporary Playlist
# ...](https://stagebibles.com/best-songs-for-villains/)
# If you're looking for the best villains music or throwing a party, these are songs you'll want to include. We
# rounded up the best villains songs to build the ultimate Playlist. ... Your Complete stylish Playlist. Best text
# lyrics prank Songs Lists for MCs: Your Complete 21st-Century Listing.
#
# [The 99 Best Songs for Villains (Our Villain Arc Playlist) -
# iSpyTunes](https://www.ispytunes.com/post/best-songs-for-villains)
# With our handpicked villain playlist with 99 of the best songs, we invite you to immerse yourself in the world of
# darkness, power, and redemption. Whether you are a storyteller seeking inspiration or a listener looking for an
# exhilarating musical experience, this playlist offers a journey into the minds and hearts of a villain.
#
# Out: None
# [Step 1: Duration 2.96 seconds| Input tokens: 11,083 | Output tokens: 207]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Output message of the LLM: ────────────────────────────────────────────────────────────────────────────────────────
# Thought: The search results provide several relevant playlists and articles. I will select a few of these and
# create a consolidated playlist suggestion, keeping in mind the "villain masquerade" and "Wayne's mansion" aspects,
# suggesting a mix of dark, elegant, and powerful tracks. I will combine the ideas from the search results and
# suggest a playlist. Since I cannot directly create a playlist, I will provide a list of songs that would fit the
# theme.
#
# I'll pick songs and themes from the search results such as "you're at a masquerade and unknowingly dancing with the
# villain", "Villain Era Playlist", "Songs for Villains" and "Masquerade party music".
#
# Here's a suggested playlist:
# 1. "Bad Guy" - Billie Eilish
# 2. "bury a friend" - Billie Eilish
# 3. "Sweet but Psycho" - Ava Max
# 4. "The Sound of Silence" - Disturbed (for a darker, more brooding moment)
# 5. "Paint it Black" - The Rolling Stones
# 6. "Sympathy for the Devil" - The Rolling Stones
# 7. "Highway to Hell" - AC/DC
# 8. "Seven Nation Army" - The White Stripes (powerful and recognizable)
# 9. "Another One Bites the Dust" - Queen
# 10. "Mad World" - Gary Jules (slower, more reflective, but still dark)
# 11. "Tainted Love" - Soft Cell (80s classic with a dark twist)
# 12. "Psycho Killer" - Talking Heads
# 13. "The Phantom of the Opera" - Andrew Lloyd Webber (classic masquerade feel)
# 14. Instrumental versions of classical pieces (e.g., Mozart's Requiem, Beethoven's Moonlight Sonata) for a more
# elegant, menacing backdrop.
#
# I will finalize the answer.
# Code:
# ```py
# final_answer("""Here's a suggested playlist for a villain masquerade party at Wayne's mansion:
#
# 1. "Bad Guy" - Billie Eilish
# 2. "bury a friend" - Billie Eilish
# 3. "Sweet but Psycho" - Ava Max
# 4. "The Sound of Silence" - Disturbed
# 5. "Paint it Black" - The Rolling Stones
# 6. "Sympathy for the Devil" - The Rolling Stones
# 7. "Highway to Hell" - AC/DC
# 8. "Seven Nation Army" - The White Stripes
# 9. "Another One Bites the Dust" - Queen
# 10. "Mad World" - Gary Jules
# 11. "Tainted Love" - Soft Cell
# 12. "Psycho Killer" - Talking Heads
# 13. "The Phantom of the Opera" - Andrew Lloyd Webber
# 14. Instrumental versions of classical pieces (e.g., Mozart's Requiem, Beethoven's Moonlight Sonata)""")
# ```<end_code>
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   final_answer("""Here's a suggested playlist for a villain masquerade party at Wayne's mansion:
#
#   1. "Bad Guy" - Billie Eilish
#   2. "bury a friend" - Billie Eilish
#   3. "Sweet but Psycho" - Ava Max
#   4. "The Sound of Silence" - Disturbed
#   5. "Paint it Black" - The Rolling Stones
#   6. "Sympathy for the Devil" - The Rolling Stones
#   7. "Highway to Hell" - AC/DC
#   8. "Seven Nation Army" - The White Stripes
#   9. "Another One Bites the Dust" - Queen
#   10. "Mad World" - Gary Jules
#   11. "Tainted Love" - Soft Cell
#   12. "Psycho Killer" - Talking Heads
#   13. "The Phantom of the Opera" - Andrew Lloyd Webber
#   14. Instrumental versions of classical pieces (e.g., Mozart's Requiem, Beethoven's Moonlight Sonata)""")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Out - Final answer: Here's a suggested playlist for a villain masquerade party at Wayne's mansion:
#
# 1. "Bad Guy" - Billie Eilish
# 2. "bury a friend" - Billie Eilish
# 3. "Sweet but Psycho" - Ava Max
# 4. "The Sound of Silence" - Disturbed
# 5. "Paint it Black" - The Rolling Stones
# 6. "Sympathy for the Devil" - The Rolling Stones
# 7. "Highway to Hell" - AC/DC
# 8. "Seven Nation Army" - The White Stripes
# 9. "Another One Bites the Dust" - Queen
# 10. "Mad World" - Gary Jules
# 11. "Tainted Love" - Soft Cell
# 12. "Psycho Killer" - Talking Heads
# 13. "The Phantom of the Opera" - Andrew Lloyd Webber
# 14. Instrumental versions of classical pieces (e.g., Mozart's Requiem, Beethoven's Moonlight Sonata)
# [Step 2: Duration 3.79 seconds| Input tokens: 22,166 | Output tokens: 414]
# 'Here\'s a suggested playlist for a villain masquerade party at Wayne\'s mansion:\n\n1. "Bad Guy" - Billie Eilish\n2. "bury a friend" - Billie Eilish\n3. "Sweet but Psycho" - Ava Max\n4. "The Sound of Silence" - Disturbed\n5. "Paint it Black" - The Rolling Stones\n6. "Sympathy for the Devil" - The Rolling Stones\n7. "Highway to Hell" - AC/DC\n8. "Seven Nation Army" - The White Stripes\n9. "Another One Bites the Dust" - Queen\n10. "Mad World" - Gary Jules\n11. "Tainted Love" - Soft Cell\n12. "Psycho Killer" - Talking Heads\n13. "The Phantom of the Opera" - Andrew Lloyd Webber\n14. Instrumental versions of classical pieces (e.g., Mozart\'s Requiem, Beethoven\'s Moonlight Sonata)'

# %% [markdown]
# What's also exciting is that shared agents are directly available as Hugging Face Spaces, allowing you to interact with them in real-time. You can explore other agents [here](https://huggingface.co/spaces/davidberenstein1957/smolagents-and-tools).
#
# For example, the _AlfredAgent_ is available [here](https://huggingface.co/spaces/sergiopaniego/AlfredAgent).

# %% [markdown]
# ### Inspecting Our Party Preparator Agent with OpenTelemetry and Langfuse 📡
#
# Full trace can be found [here](https://cloud.langfuse.com/project/cm7bq0abj025rad078ak3luwi/traces/995fc019255528e4f48cf6770b0ce27b?timestamp=2025-02-19T10%3A28%3A36.929Z).
#
# As Alfred fine-tunes the Party Preparator Agent, he's growing weary of debugging its runs. Agents, by nature, are unpredictable and difficult to inspect. But since he aims to build the ultimate Party Preparator Agent and deploy it in production, he needs robust traceability for future monitoring and analysis.
#
# Once again, `smolagents` comes to the rescue! It embraces the [OpenTelemetry](https://opentelemetry.io/) standard for instrumenting agent runs, allowing seamless inspection and logging. With the help of [Langfuse](https://langfuse.com/) and the `SmolagentsInstrumentor`, Alfred can easily track and analyze his agent’s behavior.
#
# Setting it up is straightforward!
#
# First, we need to install the necessary dependencies:

# %%
# !pip install --q opentelemetry-sdk opentelemetry-exporter-otlp openinference-instrumentation-smolagents

# %% [markdown]
# Next, Alfred has already created an account on Langfuse and has his API keys ready. If you haven’t done so yet, you can sign up for Langfuse Cloud [here](https://cloud.langfuse.com/) or explore [alternatives](https://huggingface.co/docs/smolagents/tutorials/inspect_runs).
#
# Once you have your API keys, they need to be properly configured as follows:

# %%
import os
import base64
from google.colab import userdata

LANGFUSE_PUBLIC_KEY=userdata.get("LANGFUSE_PUBLIC_KEY")
LANGFUSE_SECRET_KEY=userdata.get("LANGFUSE_SECRET_KEY")
LANGFUSE_AUTH=base64.b64encode(f"{LANGFUSE_PUBLIC_KEY}:{LANGFUSE_SECRET_KEY}".encode()).decode()

os.environ["OTEL_EXPORTER_OTLP_ENDPOINT"] = "https://cloud.langfuse.com/api/public/otel" # EU data region
# os.environ["OTEL_EXPORTER_OTLP_ENDPOINT"] = "https://us.cloud.langfuse.com/api/public/otel" # US data region
os.environ["OTEL_EXPORTER_OTLP_HEADERS"] = f"Authorization=Basic {LANGFUSE_AUTH}"

# %% [markdown]
# Finally, Alfred is ready to initialize the `SmolagentsInstrumentor` and start tracking his agent's performance.

# %%
from opentelemetry.sdk.trace import TracerProvider

from openinference.instrumentation.smolagents import SmolagentsInstrumentor
from opentelemetry.exporter.otlp.proto.http.trace_exporter import OTLPSpanExporter
from opentelemetry.sdk.trace.export import SimpleSpanProcessor

trace_provider = TracerProvider()
trace_provider.add_span_processor(SimpleSpanProcessor(OTLPSpanExporter()))

SmolagentsInstrumentor().instrument(tracer_provider=trace_provider)

# %% [markdown]
# Alfred is now connected 🔌! The runs from `smolagents` are being logged in Langfuse, giving him full visibility into the agent's behavior. With this setup, he's ready to revisit previous runs and refine his Party Preparator Agent even further.

# %%
from smolagents import CodeAgent

agent = CodeAgent(tools=[], model=gemini_model)
alfred_agent = agent.from_hub('hackyroot/AlfredAgent', trust_remote_code=True)
alfred_agent.model = gemini_model
alfred_agent.run("Give me best playlist for a party at the Wayne's mansion. The party idea is a 'villain masquerade' theme")
# Out:
# Fetching 14 files:   0%|          | 0/14 [00:00<?, ?it/s]
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Give me best playlist for a party at the Wayne's mansion. The party idea is a 'villain masquerade' theme        │
# │                                                                                                                 │
# ╰─ LiteLLMModel - gemini/gemini-2.0-flash ────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Output message of the LLM: ────────────────────────────────────────────────────────────────────────────────────────
# Thought: I need to first figure out the general musical vibe that would fit a villain masquerade party at Wayne
# Manor. I'll then use web search to find existing playlists that match this description, and combine elements from
# the best ones to create a final playlist.
# Code:
# ```py
# print(web_search("villain masquerade party music playlist"))
# print(web_search("elegant dark party music playlist"))
# print(web_search("gothic masquerade ball music"))
# ```<end_code>
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   print(web_search("villain masquerade party music playlist"))
#   print(web_search("elegant dark party music playlist"))
#   print(web_search("gothic masquerade ball music"))
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [Masquerade party music - playlist by drew - Spotify](https://open.spotify.com/playlist/3gICKSayCeN6muUWNGHeK4)
# Playlist · Masquerade party music 🎭 · 38 items · 8 saves
#
# [you're at a masquerade and unknowingly dancing with your ... - YouTube](https://m.youtube.com/watch?v=e1ic7bV9dtA)
# ahh I literally couldn't wait to post this, so here is an upload a day early!! lets be honest, we come here for the
# music and stay for the povs. I totally di...
#
# [dancing with your enemy at a masquerade ball - playlist by ... -
# Spotify](https://open.spotify.com/playlist/0zNqQEIlXMRKi3bBgccKWv)
# Playlist · dancing with your enemy at a masquerade ball · 25 items · 8.9K likes. Playlist · martika 🎧 · 25 items ·
# 8.9K likes. Sign up Log in. Resize main navigation. Loading. Company. About Jobs For the Record. Communities. For
# Artists Developers Advertising Investors Vendors.
#
# [Best villains Songs Lists for DJs: Your Complete contemporary Playlist
# ...](https://stagebibles.com/best-songs-for-villains/)
# This song is all about celebrating life and enjoying the moment. It's perfect for anyone who's ready to party and
# celebrate their hard-earned achievement. 10 Best Songs for villains. Music is one of the most essential parts of
# our lives, and it's something that everyone can enjoy. No matter what your taste in music is, there's a song out
# there ...
#
# [Songs to play at a masquerade ball -
# YouTube](https://www.youtube.com/playlist?list=PLDAD3zW4NbMiYq371qad7WS78MDCIzM2z)
# Share your videos with friends, family, and the world
#
# [Masquerade Party! - playlist by freli - Spotify](https://open.spotify.com/playlist/6P6sYHRI3ERiSOG8ljaeFz)
# Masquerade Party!🎭 · Playlist · 171 songs · 21 likes
#
# [The 99 Best Songs for Villains (Our Villain Arc Playlist) -
# iSpyTunes](https://www.ispytunes.com/post/best-songs-for-villains)
# With our handpicked villain playlist with 99 of the best songs, we invite you to immerse yourself in the world of
# darkness, power, and redemption. Whether you are a storyteller seeking inspiration or a listener looking for an
# exhilarating musical experience, this playlist offers a journey into the minds and hearts of a villain.
#
# [Masquerade Ball Music - YouTube Music](https://music.youtube.com/playlist?list=PLmfMvyItKJ0pPO3EjgXTwbiIJZWT23Sl-)
# With the YouTube Music app, enjoy over 100 million songs at your fingertips, plus albums, playlists, remixes, music
# videos, live performances, covers, and hard-to-find music you can't get anywhere else. ... Masquerade Ball Music.
# Falons Flea Market. Playlist • 2025. 63K views • 13 tracks • 2 hours, 45 minutes. Vivaldi - Four Seasons ...
#
# [Ultimate Villain Playlist: 10 Dark & Powerful
# Songs](https://theawakenbuddha.com/best-10-villain-song-unleash-darkness-playlist/)
# Creating the perfect villain playlist requires a mix of intensity, mystery, and power-packed tunes. Here's a list
# of 10 songs that embody the essence of a cinematic villain, perfect for setting the mood for dark and dramatic
# vibes. Arts & Entertainment; Business & Money;
#
# [The 75 Best Party Songs That Will Get Everyone Dancing -
# Gear4music](https://www.gear4music.com/blog/best-party-songs/)
# So, to keep things simple, we've compiled the best party songs of all time, from timeless classics to contemporary
# hits, giving you a diverse, ... s breakout song combines laid-back vocals with a catchy, rhythmic beat. It's a
# chill track yet works great on a party playlist. 59. "DNA (Loving You)" - Billy Gillies ft. Hannah Boleyn ...
# ## Search Results
#
# [The Deadly Elegant Dark Cabaret - Aradne Wiremux - playlist ... -
# Spotify](https://open.spotify.com/playlist/1HBdyQqKCsk2YMENruL6oT)
# The Deadly Elegant Dark Cabaret - Aradne Wiremux · Playlist · 24 songs · 2.4K likes
#
# [The Deadly Elegant Dark Cabaret - YouTube
# Music](https://music.youtube.com/playlist?list=PLlrR1kCXOAOTfX7jGna-j8Vucsaca9D4R)
# With the YouTube Music app, enjoy over 100 million songs at your fingertips, plus albums, playlists, remixes, music
# videos, live performances, covers, and hard-to-find music you can't get anywhere else. ... The Deadly Elegant Dark
# Cabaret. Lucie. Playlist • 2022. 771 views • 15 tracks • 56 ... The Scarring Party - Anywhere. ruhkfuture ...
#
# [The Best Playlist For A Cocktail Bar: Perfect Songs To Set The
# Mood](https://advancedmixology.com/blogs/art-of-mixology/best-playlist-for-cocktail-bar)
# When hosting a cocktail party, the music is just as important as the drinks where you want to set the mood and
# create an atmosphere that makes your guests feel relaxed and happy. A great idea is to play a good mix of songs to
# set the tone and get your guests in the mood for a night of fun and relaxation. That's why we've put together this
# list of the best songs for a cocktail party.
#
# [50 Songs on Every Event Planner's Playlist -
# Eventbrite](https://www.eventbrite.com/blog/event-planning-playlist-ds00/)
# Playing non-stop party tunes might be distracting for attendees or potential new clients. Instead, curate a list of
# songs for corporate events with a mix of genres that keeps guests energized without disturbing the flow. Below is a
# sample of a music playlist for corporate events: "24K Magic" - Bruno Mars
#
# [Dark Elegant Classical Music - YouTube](https://www.youtube.com/playlist?list=PLzOwriNHlKPUmMS4bJG2QQrTC-THbhsAj)
# Share your videos with friends, family, and the world
#
# [Elegant music - playlist by NW RECORDINGS | Spotify](https://open.spotify.com/playlist/1QwhdwML9H74GHq0uxCqzz)
# Playlist · Elegant music · 690 items · 2.9K saves. Playlist · NW RECORDINGS · 690 items · 2.9K saves. Sign up Log
# in. Your Library. English. Resize main navigation. Preview of Spotify. Sign up to get unlimited songs and podcasts
# with occasional ads. No credit card needed. Sign up free-:--
#
# [12 Rococo Inspired Party Playlist Gems That'll Set the Mood for Any
# ...](https://studentofguitar.com/rococo-playlist/)
# Ideal for cocktail parties or evening receptions, this piece invites conversation and laughter, setting a spirited
# yet elegant tone. Picture guests holding sparkling drinks, sharing stories, and dancing under twinkling fairy
# lights as the music elevates the ambiance. 3. Handel's Water Music
#
# [Gala Night - Elegant Jazz - Smooth Music for Romantic Evening, Elegant
# ...](https://music.apple.com/us/album/gala-night-elegant-jazz-smooth-music-for-romantic-evening/1437330479)
# Listen to Gala Night - Elegant Jazz - Smooth Music for Romantic Evening, Elegant Cocktail Party, Restaurant and
# Wine Bar, Beautiful Instrumental Sounds by Relaxing Piano Bar Masters on Apple Music. 2018. 30 Songs. Duration: 2
# hours, 7 minutes.
#
# [Dark Feminine Energy Playlist - Elegant music for when you feel down
# ...](https://m.youtube.com/watch?v=t_mGSZ0ygoQ)
# Discover the perfect soundtrack for embracing strength and elegance with this Dark Feminine Energy Playlist. 🎶
# Featuring beautiful melodies, rich cello ton...
#
# [Love Blues Mix - Dark & Elegant Escape - Relaxing Bourbon Blues Music
# ...](https://m.youtube.com/watch?v=Aa1dYxj1nYk)
# Subscribe: https://www.youtube.com/@SmokyBluesNightsSmoky Blues Nights is your go-to YouTube channel for deep,
# soul-stirring blues. Whether you're in the moo...
# ## Search Results
#
# [Dark Waltz Music & Masquerade Music - YouTube](https://m.youtube.com/watch?v=t3ORBn4YLw0)
# Dark waltz music and masquerade music that will take you to Gothic ballrooms, enchanted forests, & winter
# castles.🖤 If you like this spooky music & fantasy ...
#
# [Beautiful Waltz Music - Masquerade Ball [2 Hour Version]](https://m.youtube.com/watch?v=cdI9ZexmCQs)
# 🎼 Buy Masquerade Ball sheet music here :Sheet Music Plus: https://www.sheetmusicplus.com/title/20969907🎵 Buy this
# music here :iTunes : https://itunes.apple...
#
# [Stream 6. Gothic Masquerade Ball by Iridium Music -
# SoundCloud](https://soundcloud.com/iridiummusicfree/6-gothic-masquerade-ball)
# Stream 6. Gothic Masquerade Ball by Iridium Music on desktop and mobile. Play over 320 million tracks for free on
# SoundCloud.
#
# [Stream Amarra | Listen to Masquerade Ball music playlist online for
# ...](https://soundcloud.com/user-960458471/sets/masquerade-ball-music)
# Masquerade Ball music by Amarra published on 2023-08-09T00:43:35Z. Contains tracks. Dark Waltz Music - Masquerade
# Of The Ghosts by Theme Cloud ... Gothic Waltz Music - Enchanted Ballroom by Usagi published on
# 2016-06-01T20:13:09Z. Albums from this user; Playlists from this user;
#
# [Mascarade Music Playlist - Melodice](https://melodice.org/playlist/mascarade-2013/)
# All Hallows Eve Ball: 03:02: 11: Best Orchestral Dance Music (4/40) Waltz from "Cinderella" (Russia 1941)by
# Prokofiev: ... Dark Waltz Music - Masquerade of the Ghosts: 04:01: 20: The Settlers VI OST Greenlands: ... Gothic
# Waltz Music - Enchanted Ballroom:
#
# [Gothic Masquerade Ball - Iridium Music: Song Lyrics, Music Videos
# ...](https://www.shazam.com/song/1724240395/gothic-masquerade-ball)
# Listen to Gothic Masquerade Ball by Iridium Music. See lyrics and music videos, find Iridium Music tour dates, buy
# concert tickets, and more!
#
# [Beautiful Waltz Music - Masquerade Ball - SoundCloud](https://soundcloud.com/dfiechter2/masquerade-ball)
# Waltz Music Comment by Ryan Pace Sloan. This section is particularly spectacular. 2021-08-11T03:27:02Z Comment by
# Jazzyman. I think you glorify the God in the right way. 2018-07-19T17:25:07Z Buy Beautiful Waltz Music - Masquerade
# Ball. Users who like Beautiful Waltz Music - Masquerade Ball; Users who reposted Beautiful Waltz Music - Masquerade
# Ball
#
# [Beautiful Waltz Music - Masquerade Ball - YouTube](https://m.youtube.com/watch?v=lL-mcKChOIw)
# 🎼 Buy Masquerade Ball sheet music here :Sheet Music Plus: https://www.sheetmusicplus.com/title/20969907🎵 Buy this
# music here :iTunes : https://itunes.apple...
#
# [Masquerade Music - YouTube Music](https://music.youtube.com/playlist?list=PL4XaKxGqgPeUOADtmJHE2FcgCAE90cAV0)
# With the YouTube Music app, enjoy over 100 million songs at your fingertips, plus albums, playlists, remixes, music
# videos, live performances, covers, and hard-to-find music you can't get anywhere else.
#
# [Dark Waltz Music - Masquerade of the Ghosts [2 Hour Version]](https://m.youtube.com/watch?v=dPMMkEbL-EE)
# Dark waltz music about a masked ball in a dark manor where the guests are all ghosts. This music is called
# Masquerade of the Ghosts. We hope you enjoy listen...
#
# Out: None
# [Step 1: Duration 6.60 seconds| Input tokens: 11,083 | Output tokens: 207]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Output message of the LLM: ────────────────────────────────────────────────────────────────────────────────────────
# Thought: Based on the search results, a combination of dark classical, waltzes, and some modern "villain" songs
# would fit the theme. I'll need to find specific tracks to create a balanced playlist. I will now look for specific
# classical songs that fit the mood.
# Code:
# ```py
# print(web_search("dark classical music playlist elegant"))
# print(web_search("modern villain songs playlist"))
# ```<end_code>
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   print(web_search("dark classical music playlist elegant"))
#   print(web_search("modern villain songs playlist"))
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [Dark Elegant Classical Music - YouTube](https://www.youtube.com/playlist?list=PLzOwriNHlKPUmMS4bJG2QQrTC-THbhsAj)
# Share your videos with friends, family, and the world
#
# [Dark Elegant Classical Music - playlist by • y r a -
# Spotify](https://open.spotify.com/playlist/2NRpp7Mhqk6XYiCP38Y2J8)
# Dark Elegant Classical Music · Playlist · 50 songs · 82 likes
#
# [dark + elegant classical - playlist by Hannah Grace |
# Spotify](https://open.spotify.com/playlist/6JhWl0aXKsK2Wy7eTSCGfd)
# dark + elegant classical · Playlist · 43 songs · 36 likes
#
# [Dark Royalty Core Classical Music - YouTube](https://m.youtube.com/watch?v=Ty81ibUn75E)
# 🎵 Buy the album on the Official Halidon Music Store: https://bit.ly/3aRzWC6🎧 Listen to our playlist on Spotify:
# https://bit.ly/DarkRoyaltyCore💿 Order "Dar...
#
# [a dark classical playlist for reading & studying - YouTube](https://m.youtube.com/watch?v=jaiNae36bOQ)
# Immerse yourself in this hauntingly beautiful playlist of dark classical music, featuring masterpieces from
# Debussy, Chopin, Bach, Schumann, Beethoven, Mozar...
#
# [Dark Classical Music - YouTube Music](https://music.youtube.com/playlist?list=PLVjdLE-JfE_HQlj_Orpf7goH-84-gt42J)
# dark classical music Playlist 📚Genre: Classical 🎸Secondary Genre: Classical, Soundtracks, Instrumental 🎶Moods:
# DARK MELANCHOLIC WANDERING ROMANTIC BLUE 🗂️Catalog: catalogue 🏆Top 5 songs: Junior dos Santos Silva - Moonlight
# Sonata (1st Movement), Invadable Harmony - Lament, Wolfgang Amadeus Mozart - Lacrimosa, Béla Bartók - Romanian Folk
# Dances, Sz 56: III.
#
# [Best of Dark Classical Music - YouTube
# Music](https://music.youtube.com/playlist?list=OLAK5uy_kJ-Qrtbh1M0IEymkz3H3Hc3goxPGIBw-s)
# With the YouTube Music app, enjoy over 100 million songs at your fingertips, plus albums, playlists, remixes, music
# videos, live performances, covers, and hard-to-find music you can't get anywhere else. ... Best of Dark Classical
# Music. Album • 2014. 13 songs • 1 hour, 20 minutes. 1. Toccata and Fugue in D Minor, BWV 565. Marek Zborowski ...
#
# [Dark Elegant Classical Music - YouTube
# Music](https://music.youtube.com/playlist?list=PLzOwriNHlKPUmMS4bJG2QQrTC-THbhsAj)
# With the YouTube Music app, enjoy over 100 million songs at your fingertips, plus albums, playlists, remixes, music
# videos, live performances, covers, and hard-to-find music you can't get anywhere else. ... Dark Elegant Classical
# Music. Eric Piatt. Playlist • 2017. 2.3M views • 23 tracks • 4+ hours. Beethoven - Moonlight Sonata (FULL ...
#
# [Stream r.v.2308 | Listen to Dark classical music playlist online for
# ...](https://soundcloud.com/user-528712241/sets/dark-classical-music)
# Listen to Dark classical music, a playlist curated by r.v.2308 on desktop and mobile. SoundCloud Dark classical
# music by r.v.2308 published on 2021-07-04T16:24:04Z. Contains tracks. The Shadow's Bride - Dark Classical Music |
# Piano by Orxan published on 2019-04-28T19:52 ...
#
# [dark classical music - playlist by edendawni | Spotify](https://open.spotify.com/playlist/4Yz4OxGaJ6ap2BUKR4ELSZ)
# dark classical music · Playlist · 474 songs · 36.7K likes
# ## Search Results
#
# [The 99 Best Songs for Villains (Our Villain Arc Playlist) -
# iSpyTunes](https://www.ispytunes.com/post/best-songs-for-villains)
# Enter the captivating world of villain songs with our curated playlist of the 99 best songs for villains, where
# darkness and power converge. top of page. Home. Submit a Song ... Iconic villain songs from TV Shows & Movies that
# gave way to modern tracks deserve some love too. From a Disney movie to Sci-Fi universes, let's mention a few
# classics! ...
#
# [Villain Mode | Spotify Playlist](https://open.spotify.com/playlist/37i9dQZF1DX3R7OWWGN4gH)
# Playlist · Villain Mode · 100 items · 1.4M saves. Playlist · Spotify · 100 items · 1.4M saves ... Modern Slavery
# Act. UK Tax Policy. UK Gender Pay Report. ... Resize main navigation. Preview of Spotify. Sign up to get unlimited
# songs and podcasts with occasional ads. No credit card needed. Sign up free-:--Change progress-:--Change volume ...
#
# [Ultimate Villain Playlist: 10 Dark & Powerful
# Songs](https://theawakenbuddha.com/best-10-villain-song-unleash-darkness-playlist/)
# Creating the perfect villain playlist requires a mix of intensity, mystery, and power-packed tunes. Here's a list
# of 10 songs that embody the essence of a cinematic villain, perfect for setting the mood for dark and dramatic
# vibes.
#
# [Villain playlists - YouTube Music](https://music.youtube.com/playlist?list=PLPdfPTihLubiAPxLUoAjk0jfmMz0ROVie)
# With the YouTube Music app, enjoy over 100 million songs at your fingertips, plus albums, playlists, remixes, music
# videos, live performances, covers, and hard-to-find music you can't get anywhere else.
#
# [Songs to make you feel like a villain - 554 songs -
# Spotify](https://open.spotify.com/playlist/1SRTgcoCikH2tFfyuvgRBm)
# Playlist · CB · 554 items · 78.5K saves ... Playlist · Songs to make you feel like a villain · 554 items · 78.5K
# saves. Playlist · CB · 554 items · 78.5K saves. What do you want to play? CtrlK. Premium Support Download. Install
# App. Sign up Log in. Your Library. Create your first playlist It's easy, we'll help you.
#
# [Villain Songs - playlist by Rising Wave - Spotify](https://open.spotify.com/playlist/1PmcejA3LnhSUxqJlhFh8L)
# Playlist · Villain Songs 💀 · 119 items · 22.9K likes. Resize main navigation
#
# [Ultimate Villain Playlist - YouTube
# Music](https://music.youtube.com/playlist?list=PL-BnPF_Yo3_jhVn5cDGvY_zo701QMaZNx)
# A growing collection of Villain Songs, from games, to movies, and from books to comics, not to mention 'What If's'.
#
# [50 Songs About Villains - HubPages](https://discover.hubpages.com/entertainment/songs-about-villains)
# Songs Where Villains Shine. There was a time when a movie villain completely stole the show, and it wasn't just
# about the performance. The soundtrack did something sneaky—it made the bad guy feel larger than life. That theme
# song, the one that followed every sinister move, felt just as much a part of the character as the costume or the
# ...
#
# ["Unleash the Darkness: 10 Songs That Define the Perfect Villain
# Playlist"](https://theawakenbuddha.com/unleash-the-darkness-10-songs-that-define-the-perfect-villain-playlist/)
# Creating the perfect villain playlist requires a mix of intensity, mystery, and power-packed tunes. Here's a list
# of 10 songs that embody the essence of a cinematic villain, perfect for setting the mood for dark and dramatic
# vibes.
#
# [33 Songs That Make You Feel Like a Villain - Music
# Grotto](https://www.musicgrotto.com/songs-that-make-you-feel-like-a-villain/)
# This 1982 hit might be the most iconic villain song of modern music. The singer describes himself as someone who
# was evil from the moment he was born, and he will never change his ways. But combined with that famous guitar riff
# and the stuttering chorus, George Thorogood manages to make being bad sound pretty good. 14. Can't Be Tamed ...
#
# Out: None
# [Step 2: Duration 5.22 seconds| Input tokens: 22,166 | Output tokens: 414]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Output message of the LLM: ────────────────────────────────────────────────────────────────────────────────────────
# Thought: Okay, I have enough information to construct a playlist. I will now create a function that takes the
# desired length of the playlist and constructs a suitable playlist.
#
# ```py
# import random
#
# def generate_villain_masquerade_playlist(playlist_length):
#     """
#     Generates a playlist for a villain masquerade party.
#
#     Args:
#         playlist_length (int): The desired length of the playlist.
#
#     Returns:
#         list: A list of songs.
#     """
#
#     # Classical and Waltz selections
#     classical_pieces = [
#         "Moonlight Sonata (Beethoven)",
#         "Toccata and Fugue in D Minor (Bach)",
#         "Lacrimosa (Mozart)",
#         "Danse Macabre (Saint-Saëns)",
#         "Night on Bald Mountain (Mussorgsky)",
#         "Dies Irae (Various Composers)",
#         "Hall of the Mountain King (Grieg)",
#         "In the Hall of the Mountain King - Edvard Grieg",
#         "Waltz in A Minor, Op. 34 No. 2 - Frédéric Chopin",
#         "The Blue Danube Waltz - Johann Strauss II",
#         "Valse Triste - Jean Sibelius",
#         "Masquerade Waltz - Aram Khachaturian"
#     ]
#
#     # Modern Villain Song Selections
#     villain_songs = [
#         "Bad Habits - Ed Sheeran",
#         "Therefore I Am - Billie Eilish",
#         "Heathens - Twenty One Pilots",
#         "Believer - Imagine Dragons",
#         "Look What You Made Me Do - Taylor Swift",
#         "Sweet but Psycho - Ava Max",
#         "bury a friend - Billie Eilish",
#         "The Sound of Silence - Disturbed",
#         "Gangsta's Paradise - Coolio",
#         "Madness - Ruelle",
#         "Everybody Wants To Rule The World - Tears for Fears",
#         "Psycho - Red Velvet",
#         "Toxic - Britney Spears"
#     ]
#
#     playlist = []
#     num_classical = int(playlist_length * 0.6)
#     num_villain = playlist_length - num_classical
#
#     playlist.extend(random.sample(classical_pieces, min(num_classical, len(classical_pieces))))
#     playlist.extend(random.sample(villain_songs, min(num_villain, len(villain_songs))))
#
#     random.shuffle(playlist)  # Shuffle for better flow
#     return playlist
#
# playlist = generate_villain_masquerade_playlist(20)
# print(playlist)
# ```<end_code>
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import random
#
#   def generate_villain_masquerade_playlist(playlist_length):
#       """
#       Generates a playlist for a villain masquerade party.
#
#       Args:
#           playlist_length (int): The desired length of the playlist.
#
#       Returns:
#           list: A list of songs.
#       """
#
#       # Classical and Waltz selections
#       classical_pieces = [
#           "Moonlight Sonata (Beethoven)",
#           "Toccata and Fugue in D Minor (Bach)",
#           "Lacrimosa (Mozart)",
#           "Danse Macabre (Saint-Saëns)",
#           "Night on Bald Mountain (Mussorgsky)",
#           "Dies Irae (Various Composers)",
#           "Hall of the Mountain King (Grieg)",
#           "In the Hall of the Mountain King - Edvard Grieg",
#           "Waltz in A Minor, Op. 34 No. 2 - Frédéric Chopin",
#           "The Blue Danube Waltz - Johann Strauss II",
#           "Valse Triste - Jean Sibelius",
#           "Masquerade Waltz - Aram Khachaturian"
#       ]
#
#       # Modern Villain Song Selections
#       villain_songs = [
#           "Bad Habits - Ed Sheeran",
#           "Therefore I Am - Billie Eilish",
#           "Heathens - Twenty One Pilots",
#           "Believer - Imagine Dragons",
#           "Look What You Made Me Do - Taylor Swift",
#           "Sweet but Psycho - Ava Max",
#           "bury a friend - Billie Eilish",
#           "The Sound of Silence - Disturbed",
#           "Gangsta's Paradise - Coolio",
#           "Madness - Ruelle",
#           "Everybody Wants To Rule The World - Tears for Fears",
#           "Psycho - Red Velvet",
#           "Toxic - Britney Spears"
#       ]
#
#       playlist = []
#       num_classical = int(playlist_length * 0.6)
#       num_villain = playlist_length - num_classical
#
#       playlist.extend(random.sample(classical_pieces, min(num_classical, len(classical_pieces))))
#       playlist.extend(random.sample(villain_songs, min(num_villain, len(villain_songs))))
#
#       random.shuffle(playlist)  # Shuffle for better flow
#       return playlist
#
#   playlist = generate_villain_masquerade_playlist(20)
#   print(playlist)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ['Valse Triste - Jean Sibelius', 'The Blue Danube Waltz - Johann Strauss II', "Gangsta's Paradise - Coolio",
# 'Masquerade Waltz - Aram Khachaturian', 'Night on Bald Mountain (Mussorgsky)', 'Lacrimosa (Mozart)', 'Heathens -
# Twenty One Pilots', 'Danse Macabre (Saint-Saëns)', 'Moonlight Sonata (Beethoven)', 'Believer - Imagine Dragons',
# 'Sweet but Psycho - Ava Max', 'Dies Irae (Various Composers)', 'Waltz in A Minor, Op. 34 No. 2 - Frédéric Chopin',
# 'Hall of the Mountain King (Grieg)', 'Psycho - Red Velvet', 'In the Hall of the Mountain King - Edvard Grieg',
# 'Madness - Ruelle', 'Therefore I Am - Billie Eilish', 'Toccata and Fugue in D Minor (Bach)', 'Toxic - Britney
# Spears']
#
# Out: None
# [Step 3: Duration 4.67 seconds| Input tokens: 33,249 | Output tokens: 621]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 4 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Output message of the LLM: ────────────────────────────────────────────────────────────────────────────────────────
# Thought: I have generated a good playlist. I will now provide the final answer.
# Code:
# ```py
# final_answer(['Valse Triste - Jean Sibelius', 'The Blue Danube Waltz - Johann Strauss II', "Gangsta's Paradise -
# Coolio", 'Masquerade Waltz - Aram Khachaturian', 'Night on Bald Mountain (Mussorgsky)', 'Lacrimosa (Mozart)',
# 'Heathens - Twenty One Pilots', 'Danse Macabre (Saint-Saëns)', 'Moonlight Sonata (Beethoven)', 'Believer - Imagine
# Dragons', 'Sweet but Psycho - Ava Max', 'Dies Irae (Various Composers)', 'Waltz in A Minor, Op. 34 No. 2 - Frédéric
# Chopin', 'Hall of the Mountain King (Grieg)', 'Psycho - Red Velvet', 'In the Hall of the Mountain King - Edvard
# Grieg', 'Madness - Ruelle', 'Therefore I Am - Billie Eilish', 'Toccata and Fugue in D Minor (Bach)', 'Toxic -
# Britney Spears'])
# ```<end_code>
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   final_answer(['Valse Triste - Jean Sibelius', 'The Blue Danube Waltz - Johann Strauss II', "Gangsta's Paradise
#   - Coolio", 'Masquerade Waltz - Aram Khachaturian', 'Night on Bald Mountain (Mussorgsky)', 'Lacrimosa (Mozart)',
#   'Heathens - Twenty One Pilots', 'Danse Macabre (Saint-Saëns)', 'Moonlight Sonata (Beethoven)', 'Believer -
#   Imagine Dragons', 'Sweet but Psycho - Ava Max', 'Dies Irae (Various Composers)', 'Waltz in A Minor, Op. 34 No.
#   2 - Frédéric Chopin', 'Hall of the Mountain King (Grieg)', 'Psycho - Red Velvet', 'In the Hall of the Mountain
#   King - Edvard Grieg', 'Madness - Ruelle', 'Therefore I Am - Billie Eilish', 'Toccata and Fugue in D Minor
#   (Bach)', 'Toxic - Britney Spears'])
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Out - Final answer: ['Valse Triste - Jean Sibelius', 'The Blue Danube Waltz - Johann Strauss II', "Gangsta's
# Paradise - Coolio", 'Masquerade Waltz - Aram Khachaturian', 'Night on Bald Mountain (Mussorgsky)', 'Lacrimosa
# (Mozart)', 'Heathens - Twenty One Pilots', 'Danse Macabre (Saint-Saëns)', 'Moonlight Sonata (Beethoven)', 'Believer
# - Imagine Dragons', 'Sweet but Psycho - Ava Max', 'Dies Irae (Various Composers)', 'Waltz in A Minor, Op. 34 No. 2
# - Frédéric Chopin', 'Hall of the Mountain King (Grieg)', 'Psycho - Red Velvet', 'In the Hall of the Mountain King -
# Edvard Grieg', 'Madness - Ruelle', 'Therefore I Am - Billie Eilish', 'Toccata and Fugue in D Minor (Bach)', 'Toxic
# - Britney Spears']
# [Step 4: Duration 2.42 seconds| Input tokens: 44,332 | Output tokens: 828]
# ['Valse Triste - Jean Sibelius',
#  'The Blue Danube Waltz - Johann Strauss II',
#  "Gangsta's Paradise - Coolio",
#  'Masquerade Waltz - Aram Khachaturian',
#  'Night on Bald Mountain (Mussorgsky)',
#  'Lacrimosa (Mozart)',
#  'Heathens - Twenty One Pilots',
#  'Danse Macabre (Saint-Saëns)',
#  'Moonlight Sonata (Beethoven)',
#  'Believer - Imagine Dragons',
#  'Sweet but Psycho - Ava Max',
#  'Dies Irae (Various Composers)',
#  'Waltz in A Minor, Op. 34 No. 2 - Frédéric Chopin',
#  'Hall of the Mountain King (Grieg)',
#  'Psycho - Red Velvet',
#  'In the Hall of the Mountain King - Edvard Grieg',
#  'Madness - Ruelle',
#  'Therefore I Am - Billie Eilish',
#  'Toccata and Fugue in D Minor (Bach)',
#  'Toxic - Britney Spears']

# %% [markdown]
# Alfred can now access this logs [here](https://cloud.langfuse.com/project/cm7bq0abj025rad078ak3luwi/traces/995fc019255528e4f48cf6770b0ce27b?timestamp=2025-02-19T10%3A28%3A36.929Z) to review and analyze them.
#
# Meanwhile, the [suggested playlist](https://open.spotify.com/playlist/0gZMMHjuxMrrybQ7wTMTpw) sets the perfect vibe for the party preparations. Cool, right? 🎶
